# %%
import pandas as pd
import os
import numpy as np
from gensim.models import Word2Vec, FastText
#import glove
#from glove import Corpus
os.environ['KERAS_BACKEND'] = 'tensorflow'

import collections
import gc 

import keras
from keras import backend as K
from keras import regularizers
from keras.models import Sequential, Model
from keras.layers import Flatten, Dense, Dropout, Input, concatenate, Activation, Concatenate, LSTM, GRU
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, Conv1D, BatchNormalization, GRU, Convolution1D, LSTM
from keras.layers import UpSampling1D, MaxPooling1D, GlobalMaxPooling1D, GlobalAveragePooling1D,MaxPool1D
from keras.initializers import GlorotUniform


from keras.optimizers import Adam

from keras.callbacks import EarlyStopping, ModelCheckpoint, History, ReduceLROnPlateau
from keras.utils import np_utils
#from keras.backend.tensorflow_backend import set_session, clear_session, get_session
import tensorflow as tf


from sklearn.utils import class_weight
from sklearn.metrics import average_precision_score, roc_auc_score, accuracy_score, f1_score

import warnings
warnings.filterwarnings('ignore')

# %%
type_of_ner = "new"

x_train_lstm = pd.read_pickle("data/"+type_of_ner+"_x_train.pkl")
x_dev_lstm = pd.read_pickle("data/"+type_of_ner+"_x_dev.pkl")
x_test_lstm = pd.read_pickle("data/"+type_of_ner+"_x_test.pkl")

y_train = pd.read_pickle("data/"+type_of_ner+"_y_train.pkl")
y_dev = pd.read_pickle("data/"+type_of_ner+"_y_dev.pkl")
y_test = pd.read_pickle("data/"+type_of_ner+"_y_test.pkl")


ner_word2vec = pd.read_pickle("data/"+type_of_ner+"_ner_word2vec_limited_dict.pkl")
ner_fasttext = pd.read_pickle("data/"+type_of_ner+"_ner_fasttext_limited_dict.pkl")
ner_concat = pd.read_pickle("data/"+type_of_ner+"_ner_combined_limited_dict.pkl")

train_ids = pd.read_pickle("data/"+type_of_ner+"_train_ids.pkl")
dev_ids = pd.read_pickle("data/"+type_of_ner+"_dev_ids.pkl")
test_ids = pd.read_pickle("data/"+type_of_ner+"_test_ids.pkl")

# %%
def create_dataset(dict_of_ner):
    temp_data = []
    for k, v in sorted(dict_of_ner.items()):
        temp = []
        for embed in v:
            temp.append(embed)
        temp_data.append(np.mean(temp, axis = 0)) 
    return np.asarray(temp_data)

def make_prediction_cnn(model, test_data):
    probs = model.predict(test_data)
    y_pred = [1 if i>=0.5 else 0 for i in probs]
    return probs, y_pred

def save_scores_cnn(predictions, probs, ground_truth, 
                          
                          embed_name, problem_type, iteration, hidden_unit_size,
                          
                          sequence_name, type_of_ner):
    
    auc = roc_auc_score(ground_truth, probs)
    auprc = average_precision_score(ground_truth, probs)
    acc   = accuracy_score(ground_truth, predictions)
    F1    = f1_score(ground_truth, predictions)
    
    result_dict = {}    
    result_dict['auc'] = auc
    result_dict['auprc'] = auprc
    result_dict['acc'] = acc
    result_dict['F1'] = F1

    result_path = "results/cnn/"
    file_name = str(sequence_name)+"-"+str(hidden_unit_size)+"-"+embed_name
    file_name = file_name +"-"+problem_type+"-"+str(iteration)+"-"+type_of_ner+"-cnn-.p"
    pd.to_pickle(result_dict, os.path.join(result_path, file_name))

    print(auc, auprc, acc, F1)
    
def print_scores_cnn(predictions, probs, ground_truth, model_name, problem_type, iteration, hidden_unit_size):
    auc = roc_auc_score(ground_truth, probs)
    auprc = average_precision_score(ground_truth, probs)
    acc   = accuracy_score(ground_truth, predictions)
    F1    = f1_score(ground_truth, predictions)
    
    print ("AUC: ", auc, "AUPRC: ", auprc, "F1: ", F1)
    
def get_subvector_data(size, embed_name, data):
    if embed_name == "concat":
        vector_size = 200
    else:
        vector_size = 100

    x_data = {}
    for k, v in data.items():
        number_of_additional_vector = len(v) - size
        vector = []
        for i in v:
            vector.append(i)
        if number_of_additional_vector < 0: 
            number_of_additional_vector = np.abs(number_of_additional_vector)

            temp = vector[:size]
            for i in range(0, number_of_additional_vector):
                temp.append(np.zeros(vector_size))
            x_data[k] = np.asarray(temp)
        else:
            x_data[k] = np.asarray(vector[:size])

    return x_data


def proposedmodel(layer_name, number_of_unit, embedding_name, ner_limit, num_filter):
    if embedding_name == "concat":
        input_dimension = 200
    else:
        input_dimension = 100

    sequence_input = Input(shape=(24,104))

    input_img = Input(shape=(ner_limit, input_dimension), name = "cnn_input")

    convs = []
    filter_sizes = [2,3,4]


    text_conv1d = Conv1D(filters=num_filter, kernel_size=3, 
                    padding = 'valid', strides = 1, dilation_rate=1, activation='relu', 
                            kernel_initializer=tf.keras.initializers.GlorotUniform())(input_img)
    

    
    #concat_conv = keras.layers.Concatenate()([text_conv1d, text_conv1d_2, text_conv1d_3])
    text_embeddings = GlobalMaxPooling1D()(text_conv1d)
    #text_embeddings = Dense(128, activation="relu")(text_embeddings)
    
    if layer_name == "GRU":
        x = GRU(number_of_unit)(sequence_input)
    elif layer_name == "LSTM":
        x = LSTM(number_of_unit)(sequence_input)

    concatenated = keras.layers.Concatenate()([x, text_embeddings])
    #concatenated = merge([x, text_embeddings], mode='concat', concat_axis=1)

    concatenated = Dense(512, activation='relu')(concatenated)
    concatenated = Dropout(0.2)(concatenated)
    #concatenated = Dense(256, activation='relu')(concatenated)
    #concatenated = Dense(512, activation='relu')(concatenated)
    
    #concatenated = Dense(512, activation='relu')(concatenated)
    logits_regularizer = tf.keras.regularizers.L2(0.01)
    preds = Dense(1, activation='sigmoid',use_bias=False,
                         kernel_initializer=tf.keras.initializers.GlorotUniform(), 
                  kernel_regularizer=logits_regularizer)(concatenated)
    
    
    
    
    #opt = Adam(lr=1e-4, decay = 0.01)
    
    opt = Adam(lr=1e-3, decay = 0.01) 
    
    #opt = Adam(lr=0.001)

    model = Model(inputs=[sequence_input, input_img], outputs=preds)
    model.compile(loss='binary_crossentropy',
                  optimizer=opt,
                  metrics=['acc'])
    
    return model

# %%
embedding_types = ['word2vec', 'fasttext', 'concat']
embedding_dict = [ner_word2vec, ner_fasttext, ner_concat]

target_problems = ['mort_hosp', 'mort_icu', 'los_3', 'los_7']

num_epoch = 100
model_patience = 5
monitor_criteria = 'val_loss'
#monitor_criteria = 'val_acc'
batch_size = 64

filter_number = 32
ner_representation_limit = 64
activation_func = "relu"

sequence_model = "GRU"
sequence_hidden_unit = 256

maxiter = 11
for embed_dict, embed_name in zip(embedding_dict, embedding_types):    
    print ("Embedding: ", embed_name)                                                                                                          
    print("=============================")
    
    temp_train_ner = dict((k, embed_dict[k]) for k in train_ids)
    tem_dev_ner = dict((k, embed_dict[k]) for k in dev_ids)
    temp_test_ner = dict((k, embed_dict[k]) for k in test_ids)

    x_train_dict = {}
    x_dev_dict = {}
    x_test_dict = {}

    x_train_dict = get_subvector_data(ner_representation_limit, embed_name, temp_train_ner)
    x_dev_dict = get_subvector_data(ner_representation_limit, embed_name, tem_dev_ner)
    x_test_dict = get_subvector_data(ner_representation_limit, embed_name, temp_test_ner)

    x_train_dict_sorted = collections.OrderedDict(sorted(x_train_dict.items()))
    x_dev_dict_sorted = collections.OrderedDict(sorted(x_dev_dict.items()))
    x_test_dict_sorted = collections.OrderedDict(sorted(x_test_dict.items()))

    x_train_ner = tf.constant(np.array(list(x_train_dict_sorted.values())))
    x_dev_ner = tf.constant(np.array(list(x_dev_dict_sorted.values())))
    x_test_ner = tf.constant(np.array(list(x_test_dict_sorted.values())))


    
        
    for iteration in range(1,maxiter):
        print ("Iteration number: ", iteration)
    
        for each_problem in target_problems:
            print ("Problem type: ", each_problem)
            print ("__________________")
            
            
            early_stopping_monitor = EarlyStopping(monitor=monitor_criteria, patience=model_patience)
            
            best_model_name = str(ner_representation_limit)+"-basiccnn1d-"+str(embed_name)+"-"+str(each_problem)+"-"+"best_model.hdf5"
            
            checkpoint = ModelCheckpoint(best_model_name, monitor=monitor_criteria, verbose=1,
                save_best_only=True, mode='min')
            
            reduce_lr = ReduceLROnPlateau(monitor=monitor_criteria, factor=0.2,
                              patience=2, min_lr=0.00001, epsilon=1e-4, mode='min')
            

            callbacks = [early_stopping_monitor, checkpoint, reduce_lr]
            
            #model = textCNN(sequence_model, sequence_hidden_unit, embed_name, ner_representation_limit)
            model = proposedmodel(sequence_model, sequence_hidden_unit, 
                               embed_name, ner_representation_limit,filter_number)
            #print(type(x_train_lstm), type(x_train_ner), type(y_train), type(x_dev_lstm), type(x_dev_ner), type(y_dev))
            model.fit([x_train_lstm, x_train_ner], y_train[each_problem], epochs=num_epoch, verbose=1, 
                      validation_data=([x_dev_lstm,x_dev_ner], y_dev[each_problem]), callbacks=callbacks, batch_size=batch_size)
            
            
            probs, predictions = make_prediction_cnn(model, [x_test_lstm, x_test_ner])
            print_scores_cnn(predictions, probs, y_test[each_problem], embed_name, each_problem, iteration, sequence_hidden_unit)
            
            model.load_weights(best_model_name)
                      
            probs, predictions = make_prediction_cnn(model, [x_test_lstm, x_test_ner])
            save_scores_cnn(predictions, probs, y_test[each_problem], embed_name, each_problem, iteration,
                            sequence_hidden_unit, sequence_model, type_of_ner)
            del model
            K.clear_session()
            gc.collect()
# Out:
# Embedding:  word2vec
# =============================
# Iteration number:  1
# Problem type:  mort_hosp
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.2751 - acc: 0.9062
# Epoch 1: val_loss improved from inf to 0.24652, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# 242/242 [==============================] - 32s 125ms/step - loss: 0.2750 - acc: 0.9063 - val_loss: 0.2465 - val_acc: 0.9088 - lr: 0.0010
# Epoch 2/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.2183 - acc: 0.9227
# Epoch 2: val_loss improved from 0.24652 to 0.24038, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# 242/242 [==============================] - 30s 124ms/step - loss: 0.2184 - acc: 0.9227 - val_loss: 0.2404 - val_acc: 0.9111 - lr: 0.0010
# Epoch 3/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.1918 - acc: 0.9324
# Epoch 3: val_loss improved from 0.24038 to 0.23318, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# 242/242 [==============================] - 30s 123ms/step - loss: 0.1917 - acc: 0.9325 - val_loss: 0.2332 - val_acc: 0.9170 - lr: 0.0010
# Epoch 4/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.1681 - acc: 0.9402
# Epoch 4: val_loss did not improve from 0.23318
# 242/242 [==============================] - 30s 123ms/step - loss: 0.1684 - acc: 0.9402 - val_loss: 0.2438 - val_acc: 0.9156 - lr: 0.0010
# Epoch 5/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.1476 - acc: 0.9498
# Epoch 5: val_loss did not improve from 0.23318
# 242/242 [==============================] - 30s 123ms/step - loss: 0.1477 - acc: 0.9498 - val_loss: 0.2500 - val_acc: 0.9124 - lr: 0.0010
# Epoch 6/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.1267 - acc: 0.9590
# Epoch 6: val_loss did not improve from 0.23318
# 242/242 [==============================] - 30s 123ms/step - loss: 0.1266 - acc: 0.9591 - val_loss: 0.2551 - val_acc: 0.9111 - lr: 2.0000e-04
# Epoch 7/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.1215 - acc: 0.9612
# Epoch 7: val_loss did not improve from 0.23318
# 242/242 [==============================] - 30s 124ms/step - loss: 0.1214 - acc: 0.9612 - val_loss: 0.2609 - val_acc: 0.9102 - lr: 2.0000e-04
# Epoch 8/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.1180 - acc: 0.9638
# Epoch 8: val_loss did not improve from 0.23318
# 242/242 [==============================] - 30s 124ms/step - loss: 0.1179 - acc: 0.9639 - val_loss: 0.2615 - val_acc: 0.9111 - lr: 4.0000e-05
# 138/138 [==============================] - 2s 13ms/step
# AUC:  0.8648893814256097 AUPRC:  0.549097317750278 F1:  0.48177083333333326
# 138/138 [==============================] - 2s 13ms/step
# 0.8759812938050757 0.5683764795607976 0.915319826997496 0.4833333333333334
# Problem type:  mort_icu
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.2138 - acc: 0.9335
# Epoch 1: val_loss improved from inf to 0.17590, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# 242/242 [==============================] - 32s 127ms/step - loss: 0.2137 - acc: 0.9335 - val_loss: 0.1759 - val_acc: 0.9453 - lr: 0.0010
# Epoch 2/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.1578 - acc: 0.9475
# Epoch 2: val_loss improved from 0.17590 to 0.17299, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# 242/242 [==============================] - 31s 126ms/step - loss: 0.1577 - acc: 0.9475 - val_loss: 0.1730 - val_acc: 0.9453 - lr: 0.0010
# Epoch 3/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.1358 - acc: 0.9531
# Epoch 3: val_loss improved from 0.17299 to 0.16989, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# 242/242 [==============================] - 30s 126ms/step - loss: 0.1357 - acc: 0.9532 - val_loss: 0.1699 - val_acc: 0.9444 - lr: 0.0010
# Epoch 4/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.1160 - acc: 0.9595
# Epoch 4: val_loss did not improve from 0.16989
# 242/242 [==============================] - 30s 126ms/step - loss: 0.1160 - acc: 0.9595 - val_loss: 0.1761 - val_acc: 0.9439 - lr: 0.0010
# Epoch 5/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0991 - acc: 0.9678
# Epoch 5: val_loss did not improve from 0.16989
# 242/242 [==============================] - 30s 126ms/step - loss: 0.0990 - acc: 0.9678 - val_loss: 0.1819 - val_acc: 0.9439 - lr: 0.0010
# Epoch 6/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0804 - acc: 0.9751
# Epoch 6: val_loss did not improve from 0.16989
# 242/242 [==============================] - 30s 126ms/step - loss: 0.0805 - acc: 0.9751 - val_loss: 0.1861 - val_acc: 0.9416 - lr: 2.0000e-04
# Epoch 7/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0765 - acc: 0.9776
# Epoch 7: val_loss did not improve from 0.16989
# 242/242 [==============================] - 30s 126ms/step - loss: 0.0765 - acc: 0.9776 - val_loss: 0.1895 - val_acc: 0.9430 - lr: 2.0000e-04
# Epoch 8/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0741 - acc: 0.9781
# Epoch 8: val_loss did not improve from 0.16989
# 242/242 [==============================] - 30s 126ms/step - loss: 0.0743 - acc: 0.9780 - val_loss: 0.1900 - val_acc: 0.9416 - lr: 4.0000e-05
# 138/138 [==============================] - 2s 14ms/step
# AUC:  0.8657946636727185 AUPRC:  0.49957811810529834 F1:  0.44889779559118237
# 138/138 [==============================] - 2s 14ms/step
# 0.8842619413088321 0.5235349242273559 0.9426360118370134 0.45922746781115875
# Problem type:  los_3
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.6633 - acc: 0.6324
# Epoch 1: val_loss improved from inf to 0.62107, saving model to 64-basiccnn1d-word2vec-los_3-best_model.hdf5
# 242/242 [==============================] - 33s 128ms/step - loss: 0.6631 - acc: 0.6326 - val_loss: 0.6211 - val_acc: 0.6776 - lr: 0.0010
# Epoch 2/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.6125 - acc: 0.6827
# Epoch 2: val_loss improved from 0.62107 to 0.61538, saving model to 64-basiccnn1d-word2vec-los_3-best_model.hdf5
# 242/242 [==============================] - 31s 126ms/step - loss: 0.6125 - acc: 0.6826 - val_loss: 0.6154 - val_acc: 0.6835 - lr: 0.0010
# Epoch 3/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.5845 - acc: 0.7095
# Epoch 3: val_loss did not improve from 0.61538
# 242/242 [==============================] - 31s 126ms/step - loss: 0.5844 - acc: 0.7096 - val_loss: 0.6191 - val_acc: 0.6744 - lr: 0.0010
# Epoch 4/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.5565 - acc: 0.7273
# Epoch 4: val_loss did not improve from 0.61538
# 242/242 [==============================] - 30s 126ms/step - loss: 0.5564 - acc: 0.7273 - val_loss: 0.6221 - val_acc: 0.6781 - lr: 0.0010
# Epoch 5/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.5228 - acc: 0.7551
# Epoch 5: val_loss did not improve from 0.61538
# 242/242 [==============================] - 30s 126ms/step - loss: 0.5227 - acc: 0.7551 - val_loss: 0.6258 - val_acc: 0.6735 - lr: 2.0000e-04
# Epoch 6/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.5151 - acc: 0.7615
# Epoch 6: val_loss did not improve from 0.61538
# 242/242 [==============================] - 31s 126ms/step - loss: 0.5151 - acc: 0.7616 - val_loss: 0.6296 - val_acc: 0.6749 - lr: 2.0000e-04
# Epoch 7/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.5098 - acc: 0.7659
# Epoch 7: val_loss did not improve from 0.61538
# 242/242 [==============================] - 30s 126ms/step - loss: 0.5096 - acc: 0.7661 - val_loss: 0.6300 - val_acc: 0.6731 - lr: 4.0000e-05
# 138/138 [==============================] - 2s 14ms/step
# AUC:  0.6956641408206776 AUPRC:  0.642437499056592 F1:  0.5738782509288367
# 138/138 [==============================] - 2s 13ms/step
# 0.6956932526248261 0.6412557560945447 0.6590029592533576 0.5630105017502918
# Problem type:  los_7
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.2915 - acc: 0.9182
# Epoch 1: val_loss improved from inf to 0.26424, saving model to 64-basiccnn1d-word2vec-los_7-best_model.hdf5
# 242/242 [==============================] - 32s 128ms/step - loss: 0.2917 - acc: 0.9182 - val_loss: 0.2642 - val_acc: 0.9229 - lr: 0.0010
# Epoch 2/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.2453 - acc: 0.9230
# Epoch 2: val_loss improved from 0.26424 to 0.26265, saving model to 64-basiccnn1d-word2vec-los_7-best_model.hdf5
# 242/242 [==============================] - 30s 125ms/step - loss: 0.2453 - acc: 0.9229 - val_loss: 0.2626 - val_acc: 0.9234 - lr: 0.0010
# Epoch 3/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.2276 - acc: 0.9241
# Epoch 3: val_loss did not improve from 0.26265
# 242/242 [==============================] - 30s 125ms/step - loss: 0.2275 - acc: 0.9242 - val_loss: 0.2630 - val_acc: 0.9220 - lr: 0.0010
# Epoch 4/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.2088 - acc: 0.9275
# Epoch 4: val_loss did not improve from 0.26265
# 242/242 [==============================] - 30s 125ms/step - loss: 0.2090 - acc: 0.9275 - val_loss: 0.2699 - val_acc: 0.9197 - lr: 0.0010
# Epoch 5/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.1883 - acc: 0.9333
# Epoch 5: val_loss did not improve from 0.26265
# 242/242 [==============================] - 30s 125ms/step - loss: 0.1882 - acc: 0.9334 - val_loss: 0.2739 - val_acc: 0.9188 - lr: 2.0000e-04
# Epoch 6/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.1838 - acc: 0.9354
# Epoch 6: val_loss did not improve from 0.26265
# 242/242 [==============================] - 30s 126ms/step - loss: 0.1838 - acc: 0.9353 - val_loss: 0.2764 - val_acc: 0.9193 - lr: 2.0000e-04
# Epoch 7/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.1798 - acc: 0.9360
# Epoch 7: val_loss did not improve from 0.26265
# 242/242 [==============================] - 30s 126ms/step - loss: 0.1797 - acc: 0.9361 - val_loss: 0.2771 - val_acc: 0.9193 - lr: 4.0000e-05
# 138/138 [==============================] - 2s 13ms/step
# AUC:  0.7140500179744664 AUPRC:  0.20333950972702203 F1:  0.08977556109725687
# 138/138 [==============================] - 2s 13ms/step
# 0.728842933936492 0.21480448252501813 0.9196448895970862 0.011204481792717089
# Iteration number:  2
# Problem type:  mort_hosp
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.2742 - acc: 0.9077
# Epoch 1: val_loss improved from inf to 0.23593, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# 242/242 [==============================] - 32s 127ms/step - loss: 0.2740 - acc: 0.9078 - val_loss: 0.2359 - val_acc: 0.9138 - lr: 0.0010
# Epoch 2/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.2141 - acc: 0.9236
# Epoch 2: val_loss did not improve from 0.23593
# 242/242 [==============================] - 30s 126ms/step - loss: 0.2146 - acc: 0.9234 - val_loss: 0.2370 - val_acc: 0.9124 - lr: 0.0010
# Epoch 3/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.1865 - acc: 0.9315
# Epoch 3: val_loss did not improve from 0.23593
# 242/242 [==============================] - 30s 126ms/step - loss: 0.1863 - acc: 0.9315 - val_loss: 0.2462 - val_acc: 0.9129 - lr: 0.0010
# Epoch 4/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.1587 - acc: 0.9439
# Epoch 4: val_loss did not improve from 0.23593
# 242/242 [==============================] - 30s 126ms/step - loss: 0.1586 - acc: 0.9439 - val_loss: 0.2466 - val_acc: 0.9124 - lr: 2.0000e-04
# Epoch 5/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.1512 - acc: 0.9466
# Epoch 5: val_loss did not improve from 0.23593
# 242/242 [==============================] - 30s 126ms/step - loss: 0.1512 - acc: 0.9466 - val_loss: 0.2494 - val_acc: 0.9134 - lr: 2.0000e-04
# Epoch 6/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.1469 - acc: 0.9492
# Epoch 6: val_loss did not improve from 0.23593
# 242/242 [==============================] - 31s 126ms/step - loss: 0.1469 - acc: 0.9492 - val_loss: 0.2500 - val_acc: 0.9111 - lr: 4.0000e-05
# 138/138 [==============================] - 2s 14ms/step
# AUC:  0.8755053328393396 AUPRC:  0.5699015917066363 F1:  0.47913862718707945
# 138/138 [==============================] - 2s 14ms/step
# 0.8800643940760073 0.568957069111563 0.918506715228773 0.471976401179941
# Problem type:  mort_icu
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.2127 - acc: 0.9360
# Epoch 1: val_loss improved from inf to 0.17144, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# 242/242 [==============================] - 33s 130ms/step - loss: 0.2125 - acc: 0.9361 - val_loss: 0.1714 - val_acc: 0.9448 - lr: 0.0010
# Epoch 2/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.1564 - acc: 0.9475
# Epoch 2: val_loss improved from 0.17144 to 0.16908, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# 242/242 [==============================] - 31s 128ms/step - loss: 0.1563 - acc: 0.9475 - val_loss: 0.1691 - val_acc: 0.9444 - lr: 0.0010
# Epoch 3/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.1312 - acc: 0.9541
# Epoch 3: val_loss did not improve from 0.16908
# 242/242 [==============================] - 31s 128ms/step - loss: 0.1314 - acc: 0.9540 - val_loss: 0.1715 - val_acc: 0.9462 - lr: 0.0010
# Epoch 4/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.1098 - acc: 0.9630
# Epoch 4: val_loss did not improve from 0.16908
# 242/242 [==============================] - 31s 128ms/step - loss: 0.1098 - acc: 0.9630 - val_loss: 0.1787 - val_acc: 0.9403 - lr: 0.0010
# Epoch 5/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0876 - acc: 0.9721
# Epoch 5: val_loss did not improve from 0.16908
# 242/242 [==============================] - 31s 128ms/step - loss: 0.0876 - acc: 0.9721 - val_loss: 0.1810 - val_acc: 0.9416 - lr: 2.0000e-04
# Epoch 6/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0841 - acc: 0.9732
# Epoch 6: val_loss did not improve from 0.16908
# 242/242 [==============================] - 31s 128ms/step - loss: 0.0842 - acc: 0.9732 - val_loss: 0.1831 - val_acc: 0.9416 - lr: 2.0000e-04
# Epoch 7/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0799 - acc: 0.9754
# Epoch 7: val_loss did not improve from 0.16908
# 242/242 [==============================] - 31s 128ms/step - loss: 0.0799 - acc: 0.9754 - val_loss: 0.1846 - val_acc: 0.9412 - lr: 4.0000e-05
# 138/138 [==============================] - 2s 14ms/step
# AUC:  0.8744923118723679 AUPRC:  0.502858275613592 F1:  0.468
# 138/138 [==============================] - 2s 15ms/step
# 0.8842939524018472 0.5149146823514402 0.9428636467106761 0.4308390022675737
# Problem type:  los_3
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.6690 - acc: 0.6310
# Epoch 1: val_loss improved from inf to 0.62447, saving model to 64-basiccnn1d-word2vec-los_3-best_model.hdf5
# 242/242 [==============================] - 33s 129ms/step - loss: 0.6691 - acc: 0.6310 - val_loss: 0.6245 - val_acc: 0.6708 - lr: 0.0010
# Epoch 2/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.6153 - acc: 0.6776
# Epoch 2: val_loss improved from 0.62447 to 0.62347, saving model to 64-basiccnn1d-word2vec-los_3-best_model.hdf5
# 242/242 [==============================] - 31s 128ms/step - loss: 0.6153 - acc: 0.6776 - val_loss: 0.6235 - val_acc: 0.6671 - lr: 0.0010
# Epoch 3/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.5888 - acc: 0.7010
# Epoch 3: val_loss improved from 0.62347 to 0.61938, saving model to 64-basiccnn1d-word2vec-los_3-best_model.hdf5
# 242/242 [==============================] - 31s 128ms/step - loss: 0.5887 - acc: 0.7011 - val_loss: 0.6194 - val_acc: 0.6671 - lr: 0.0010
# Epoch 4/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.5627 - acc: 0.7246
# Epoch 4: val_loss did not improve from 0.61938
# 242/242 [==============================] - 31s 127ms/step - loss: 0.5626 - acc: 0.7249 - val_loss: 0.6227 - val_acc: 0.6808 - lr: 0.0010
# Epoch 5/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.5365 - acc: 0.7416
# Epoch 5: val_loss did not improve from 0.61938
# 242/242 [==============================] - 31s 128ms/step - loss: 0.5366 - acc: 0.7414 - val_loss: 0.6291 - val_acc: 0.6667 - lr: 0.0010
# Epoch 6/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.5070 - acc: 0.7665
# Epoch 6: val_loss did not improve from 0.61938
# 242/242 [==============================] - 31s 127ms/step - loss: 0.5071 - acc: 0.7664 - val_loss: 0.6336 - val_acc: 0.6685 - lr: 2.0000e-04
# Epoch 7/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.4989 - acc: 0.7707
# Epoch 7: val_loss did not improve from 0.61938
# 242/242 [==============================] - 31s 128ms/step - loss: 0.4989 - acc: 0.7706 - val_loss: 0.6360 - val_acc: 0.6694 - lr: 2.0000e-04
# Epoch 8/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.4939 - acc: 0.7745
# Epoch 8: val_loss did not improve from 0.61938
# 242/242 [==============================] - 31s 128ms/step - loss: 0.4941 - acc: 0.7744 - val_loss: 0.6368 - val_acc: 0.6708 - lr: 4.0000e-05
# 138/138 [==============================] - 2s 14ms/step
# AUC:  0.6887524692102973 AUPRC:  0.6278828080497911 F1:  0.5684990031330105
# 138/138 [==============================] - 2s 14ms/step
# 0.6913973030824636 0.6323833297936321 0.6594582290006828 0.5394088669950738
# Problem type:  los_7
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.2854 - acc: 0.9192
# Epoch 1: val_loss improved from inf to 0.25958, saving model to 64-basiccnn1d-word2vec-los_7-best_model.hdf5
# 242/242 [==============================] - 33s 129ms/step - loss: 0.2854 - acc: 0.9192 - val_loss: 0.2596 - val_acc: 0.9238 - lr: 0.0010
# Epoch 2/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.2449 - acc: 0.9221
# Epoch 2: val_loss did not improve from 0.25958
# 242/242 [==============================] - 31s 128ms/step - loss: 0.2448 - acc: 0.9222 - val_loss: 0.2623 - val_acc: 0.9238 - lr: 0.0010
# Epoch 3/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.2265 - acc: 0.9234
# Epoch 3: val_loss did not improve from 0.25958
# 242/242 [==============================] - 31s 128ms/step - loss: 0.2265 - acc: 0.9234 - val_loss: 0.2622 - val_acc: 0.9234 - lr: 0.0010
# Epoch 4/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.2075 - acc: 0.9263
# Epoch 4: val_loss did not improve from 0.25958
# 242/242 [==============================] - 31s 128ms/step - loss: 0.2074 - acc: 0.9263 - val_loss: 0.2632 - val_acc: 0.9229 - lr: 2.0000e-04
# Epoch 5/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.2022 - acc: 0.9271
# Epoch 5: val_loss did not improve from 0.25958
# 242/242 [==============================] - 31s 128ms/step - loss: 0.2023 - acc: 0.9271 - val_loss: 0.2651 - val_acc: 0.9225 - lr: 2.0000e-04
# Epoch 6/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.1984 - acc: 0.9275
# Epoch 6: val_loss did not improve from 0.25958
# 242/242 [==============================] - 31s 128ms/step - loss: 0.1983 - acc: 0.9276 - val_loss: 0.2647 - val_acc: 0.9207 - lr: 4.0000e-05
# 138/138 [==============================] - 2s 14ms/step
# AUC:  0.7198221297155 AUPRC:  0.20843466732559363 F1:  0.04289544235924933
# 138/138 [==============================] - 2s 15ms/step
# 0.7251662113601426 0.19858104637078494 0.919189619849761 0.0
# Iteration number:  3
# Problem type:  mort_hosp
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.2745 - acc: 0.9071
# Epoch 1: val_loss improved from inf to 0.24181, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# 242/242 [==============================] - 33s 129ms/step - loss: 0.2745 - acc: 0.9071 - val_loss: 0.2418 - val_acc: 0.9184 - lr: 0.0010
# Epoch 2/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.2175 - acc: 0.9212
# Epoch 2: val_loss improved from 0.24181 to 0.23788, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# 242/242 [==============================] - 31s 128ms/step - loss: 0.2174 - acc: 0.9212 - val_loss: 0.2379 - val_acc: 0.9152 - lr: 0.0010
# Epoch 3/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.1898 - acc: 0.9321
# Epoch 3: val_loss did not improve from 0.23788
# 242/242 [==============================] - 31s 128ms/step - loss: 0.1897 - acc: 0.9321 - val_loss: 0.2414 - val_acc: 0.9143 - lr: 0.0010
# Epoch 4/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.1629 - acc: 0.9415
# Epoch 4: val_loss did not improve from 0.23788
# 242/242 [==============================] - 31s 128ms/step - loss: 0.1628 - acc: 0.9416 - val_loss: 0.2507 - val_acc: 0.9124 - lr: 0.0010
# Epoch 5/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.1394 - acc: 0.9525
# Epoch 5: val_loss did not improve from 0.23788
# 242/242 [==============================] - 31s 128ms/step - loss: 0.1394 - acc: 0.9525 - val_loss: 0.2553 - val_acc: 0.9120 - lr: 2.0000e-04
# Epoch 6/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.1339 - acc: 0.9553
# Epoch 6: val_loss did not improve from 0.23788
# 242/242 [==============================] - 31s 128ms/step - loss: 0.1338 - acc: 0.9553 - val_loss: 0.2580 - val_acc: 0.9102 - lr: 2.0000e-04
# Epoch 7/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.1294 - acc: 0.9579
# Epoch 7: val_loss did not improve from 0.23788
# 242/242 [==============================] - 31s 128ms/step - loss: 0.1293 - acc: 0.9579 - val_loss: 0.2589 - val_acc: 0.9111 - lr: 4.0000e-05
# 138/138 [==============================] - 2s 14ms/step
# AUC:  0.8711757820568725 AUPRC:  0.5545570889180816 F1:  0.4713715046604528
# 138/138 [==============================] - 2s 14ms/step
# 0.881163311988861 0.5748110294332047 0.9146369223765081 0.45095168374816985
# Problem type:  mort_icu
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.2154 - acc: 0.9356
# Epoch 1: val_loss improved from inf to 0.17677, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# 242/242 [==============================] - 33s 130ms/step - loss: 0.2152 - acc: 0.9356 - val_loss: 0.1768 - val_acc: 0.9435 - lr: 0.0010
# Epoch 2/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.1580 - acc: 0.9475
# Epoch 2: val_loss improved from 0.17677 to 0.17595, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# 242/242 [==============================] - 31s 127ms/step - loss: 0.1580 - acc: 0.9475 - val_loss: 0.1760 - val_acc: 0.9439 - lr: 0.0010
# Epoch 3/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.1353 - acc: 0.9542
# Epoch 3: val_loss improved from 0.17595 to 0.17143, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# 242/242 [==============================] - 31s 128ms/step - loss: 0.1352 - acc: 0.9543 - val_loss: 0.1714 - val_acc: 0.9457 - lr: 0.0010
# Epoch 4/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.1148 - acc: 0.9608
# Epoch 4: val_loss did not improve from 0.17143
# 242/242 [==============================] - 31s 127ms/step - loss: 0.1147 - acc: 0.9608 - val_loss: 0.1767 - val_acc: 0.9394 - lr: 0.0010
# Epoch 5/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0975 - acc: 0.9695
# Epoch 5: val_loss did not improve from 0.17143
# 242/242 [==============================] - 31s 128ms/step - loss: 0.0974 - acc: 0.9696 - val_loss: 0.1884 - val_acc: 0.9380 - lr: 0.0010
# Epoch 6/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0811 - acc: 0.9762
# Epoch 6: val_loss did not improve from 0.17143
# 242/242 [==============================] - 31s 127ms/step - loss: 0.0811 - acc: 0.9762 - val_loss: 0.1903 - val_acc: 0.9394 - lr: 2.0000e-04
# Epoch 7/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0772 - acc: 0.9778
# Epoch 7: val_loss did not improve from 0.17143
# 242/242 [==============================] - 31s 128ms/step - loss: 0.0771 - acc: 0.9778 - val_loss: 0.1912 - val_acc: 0.9371 - lr: 2.0000e-04
# Epoch 8/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0746 - acc: 0.9784
# Epoch 8: val_loss did not improve from 0.17143
# 242/242 [==============================] - 31s 128ms/step - loss: 0.0748 - acc: 0.9784 - val_loss: 0.1919 - val_acc: 0.9375 - lr: 4.0000e-05
# 138/138 [==============================] - 2s 14ms/step
# AUC:  0.8706470769187528 AUPRC:  0.49125714485942534 F1:  0.4532803180914512
# 138/138 [==============================] - 2s 14ms/step
# 0.8854151214157336 0.5129754546395977 0.9392214887320738 0.44720496894409933
# Problem type:  los_3
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.6676 - acc: 0.6341
# Epoch 1: val_loss improved from inf to 0.62085, saving model to 64-basiccnn1d-word2vec-los_3-best_model.hdf5
# 242/242 [==============================] - 33s 129ms/step - loss: 0.6676 - acc: 0.6342 - val_loss: 0.6209 - val_acc: 0.6799 - lr: 0.0010
# Epoch 2/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.6146 - acc: 0.6819
# Epoch 2: val_loss improved from 0.62085 to 0.61749, saving model to 64-basiccnn1d-word2vec-los_3-best_model.hdf5
# 242/242 [==============================] - 31s 128ms/step - loss: 0.6147 - acc: 0.6818 - val_loss: 0.6175 - val_acc: 0.6721 - lr: 0.0010
# Epoch 3/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.5878 - acc: 0.7014
# Epoch 3: val_loss did not improve from 0.61749
# 242/242 [==============================] - 31s 128ms/step - loss: 0.5876 - acc: 0.7015 - val_loss: 0.6217 - val_acc: 0.6685 - lr: 0.0010
# Epoch 4/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.5619 - acc: 0.7238
# Epoch 4: val_loss did not improve from 0.61749
# 242/242 [==============================] - 31s 128ms/step - loss: 0.5620 - acc: 0.7238 - val_loss: 0.6228 - val_acc: 0.6607 - lr: 0.0010
# Epoch 5/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.5314 - acc: 0.7501
# Epoch 5: val_loss did not improve from 0.61749
# 242/242 [==============================] - 31s 127ms/step - loss: 0.5316 - acc: 0.7499 - val_loss: 0.6236 - val_acc: 0.6680 - lr: 2.0000e-04
# Epoch 6/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.5240 - acc: 0.7530
# Epoch 6: val_loss did not improve from 0.61749
# 242/242 [==============================] - 31s 128ms/step - loss: 0.5240 - acc: 0.7531 - val_loss: 0.6285 - val_acc: 0.6694 - lr: 2.0000e-04
# Epoch 7/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.5199 - acc: 0.7560
# Epoch 7: val_loss did not improve from 0.61749
# 242/242 [==============================] - 31s 128ms/step - loss: 0.5198 - acc: 0.7561 - val_loss: 0.6278 - val_acc: 0.6694 - lr: 4.0000e-05
# 138/138 [==============================] - 2s 15ms/step
# AUC:  0.692891003288046 AUPRC:  0.6379808717647001 F1:  0.5719227443067166
# 138/138 [==============================] - 2s 14ms/step
# 0.6960505338575576 0.6364498728166225 0.6642385613475984 0.5493431102963642
# Problem type:  los_7
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.2820 - acc: 0.9209
# Epoch 1: val_loss improved from inf to 0.26046, saving model to 64-basiccnn1d-word2vec-los_7-best_model.hdf5
# 242/242 [==============================] - 33s 129ms/step - loss: 0.2818 - acc: 0.9210 - val_loss: 0.2605 - val_acc: 0.9238 - lr: 0.0010
# Epoch 2/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.2399 - acc: 0.9228
# Epoch 2: val_loss did not improve from 0.26046
# 242/242 [==============================] - 31s 127ms/step - loss: 0.2401 - acc: 0.9228 - val_loss: 0.2612 - val_acc: 0.9243 - lr: 0.0010
# Epoch 3/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.2191 - acc: 0.9257
# Epoch 3: val_loss improved from 0.26046 to 0.26036, saving model to 64-basiccnn1d-word2vec-los_7-best_model.hdf5
# 242/242 [==============================] - 31s 127ms/step - loss: 0.2190 - acc: 0.9257 - val_loss: 0.2604 - val_acc: 0.9225 - lr: 0.0010
# Epoch 4/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.1983 - acc: 0.9302
# Epoch 4: val_loss did not improve from 0.26036
# 242/242 [==============================] - 31s 127ms/step - loss: 0.1982 - acc: 0.9302 - val_loss: 0.2708 - val_acc: 0.9211 - lr: 0.0010
# Epoch 5/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.1745 - acc: 0.9383
# Epoch 5: val_loss did not improve from 0.26036
# 242/242 [==============================] - 31s 127ms/step - loss: 0.1745 - acc: 0.9383 - val_loss: 0.2833 - val_acc: 0.9161 - lr: 0.0010
# Epoch 6/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.1516 - acc: 0.9484
# Epoch 6: val_loss did not improve from 0.26036
# 242/242 [==============================] - 31s 127ms/step - loss: 0.1516 - acc: 0.9484 - val_loss: 0.2889 - val_acc: 0.9193 - lr: 2.0000e-04
# Epoch 7/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.1457 - acc: 0.9489
# Epoch 7: val_loss did not improve from 0.26036
# 242/242 [==============================] - 31s 127ms/step - loss: 0.1456 - acc: 0.9490 - val_loss: 0.2932 - val_acc: 0.9175 - lr: 2.0000e-04
# Epoch 8/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.1407 - acc: 0.9505
# Epoch 8: val_loss did not improve from 0.26036
# 242/242 [==============================] - 31s 127ms/step - loss: 0.1407 - acc: 0.9506 - val_loss: 0.2943 - val_acc: 0.9175 - lr: 4.0000e-05
# 138/138 [==============================] - 2s 14ms/step
# AUC:  0.7051809825948415 AUPRC:  0.19628563809094957 F1:  0.1324200913242009
# 138/138 [==============================] - 2s 14ms/step
# 0.7412096466233881 0.2247042003244572 0.9201001593444116 0.07387862796833773
# Iteration number:  4
# Problem type:  mort_hosp
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.2785 - acc: 0.9037
# Epoch 1: val_loss improved from inf to 0.24486, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# 242/242 [==============================] - 32s 128ms/step - loss: 0.2784 - acc: 0.9037 - val_loss: 0.2449 - val_acc: 0.9179 - lr: 0.0010
# Epoch 2/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.2182 - acc: 0.9214
# Epoch 2: val_loss improved from 0.24486 to 0.24156, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# 242/242 [==============================] - 31s 126ms/step - loss: 0.2184 - acc: 0.9212 - val_loss: 0.2416 - val_acc: 0.9115 - lr: 0.0010
# Epoch 3/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.1940 - acc: 0.9303
# Epoch 3: val_loss improved from 0.24156 to 0.23710, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# 242/242 [==============================] - 31s 126ms/step - loss: 0.1941 - acc: 0.9303 - val_loss: 0.2371 - val_acc: 0.9111 - lr: 0.0010
# Epoch 4/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.1692 - acc: 0.9385
# Epoch 4: val_loss did not improve from 0.23710
# 242/242 [==============================] - 31s 126ms/step - loss: 0.1691 - acc: 0.9385 - val_loss: 0.2494 - val_acc: 0.9115 - lr: 0.0010
# Epoch 5/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.1491 - acc: 0.9473
# Epoch 5: val_loss did not improve from 0.23710
# 242/242 [==============================] - 31s 126ms/step - loss: 0.1491 - acc: 0.9473 - val_loss: 0.2633 - val_acc: 0.9106 - lr: 0.0010
# Epoch 6/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.1269 - acc: 0.9570
# Epoch 6: val_loss did not improve from 0.23710
# 242/242 [==============================] - 31s 126ms/step - loss: 0.1269 - acc: 0.9571 - val_loss: 0.2676 - val_acc: 0.9093 - lr: 2.0000e-04
# Epoch 7/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.1214 - acc: 0.9603
# Epoch 7: val_loss did not improve from 0.23710
# 242/242 [==============================] - 31s 126ms/step - loss: 0.1216 - acc: 0.9602 - val_loss: 0.2711 - val_acc: 0.9102 - lr: 2.0000e-04
# Epoch 8/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.1181 - acc: 0.9622
# Epoch 8: val_loss did not improve from 0.23710
# 242/242 [==============================] - 31s 126ms/step - loss: 0.1180 - acc: 0.9622 - val_loss: 0.2722 - val_acc: 0.9097 - lr: 4.0000e-05
# 138/138 [==============================] - 2s 14ms/step
# AUC:  0.8681853154839774 AUPRC:  0.5430721078935503 F1:  0.4627659574468085
# 138/138 [==============================] - 2s 14ms/step
# 0.8766561638311197 0.5558290132746093 0.9114500341452311 0.4402877697841726
# Problem type:  mort_icu
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.2089 - acc: 0.9363
# Epoch 1: val_loss improved from inf to 0.17366, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# 242/242 [==============================] - 33s 128ms/step - loss: 0.2090 - acc: 0.9363 - val_loss: 0.1737 - val_acc: 0.9421 - lr: 0.0010
# Epoch 2/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.1576 - acc: 0.9473
# Epoch 2: val_loss improved from 0.17366 to 0.16874, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# 242/242 [==============================] - 31s 127ms/step - loss: 0.1574 - acc: 0.9473 - val_loss: 0.1687 - val_acc: 0.9444 - lr: 0.0010
# Epoch 3/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.1339 - acc: 0.9541
# Epoch 3: val_loss did not improve from 0.16874
# 242/242 [==============================] - 31s 126ms/step - loss: 0.1339 - acc: 0.9541 - val_loss: 0.1700 - val_acc: 0.9435 - lr: 0.0010
# Epoch 4/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.1147 - acc: 0.9621
# Epoch 4: val_loss did not improve from 0.16874
# 242/242 [==============================] - 31s 126ms/step - loss: 0.1148 - acc: 0.9620 - val_loss: 0.1788 - val_acc: 0.9435 - lr: 0.0010
# Epoch 5/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0957 - acc: 0.9685
# Epoch 5: val_loss did not improve from 0.16874
# 242/242 [==============================] - 31s 126ms/step - loss: 0.0957 - acc: 0.9685 - val_loss: 0.1793 - val_acc: 0.9462 - lr: 2.0000e-04
# Epoch 6/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0914 - acc: 0.9701
# Epoch 6: val_loss did not improve from 0.16874
# 242/242 [==============================] - 31s 126ms/step - loss: 0.0914 - acc: 0.9701 - val_loss: 0.1808 - val_acc: 0.9457 - lr: 2.0000e-04
# Epoch 7/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0874 - acc: 0.9715
# Epoch 7: val_loss did not improve from 0.16874
# 242/242 [==============================] - 31s 126ms/step - loss: 0.0874 - acc: 0.9715 - val_loss: 0.1812 - val_acc: 0.9457 - lr: 4.0000e-05
# 138/138 [==============================] - 2s 14ms/step
# AUC:  0.8805353816268818 AUPRC:  0.5142112085673727 F1:  0.47484909456740454
# 138/138 [==============================] - 2s 14ms/step
# 0.8912348942775096 0.5257879057781549 0.9451399954473025 0.45102505694760814
# Problem type:  los_3
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.6679 - acc: 0.6293
# Epoch 1: val_loss improved from inf to 0.62394, saving model to 64-basiccnn1d-word2vec-los_3-best_model.hdf5
# 242/242 [==============================] - 32s 128ms/step - loss: 0.6679 - acc: 0.6294 - val_loss: 0.6239 - val_acc: 0.6808 - lr: 0.0010
# Epoch 2/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.6142 - acc: 0.6777
# Epoch 2: val_loss improved from 0.62394 to 0.61686, saving model to 64-basiccnn1d-word2vec-los_3-best_model.hdf5
# 242/242 [==============================] - 31s 126ms/step - loss: 0.6141 - acc: 0.6779 - val_loss: 0.6169 - val_acc: 0.6776 - lr: 0.0010
# Epoch 3/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.5880 - acc: 0.7045
# Epoch 3: val_loss did not improve from 0.61686
# 242/242 [==============================] - 31s 127ms/step - loss: 0.5882 - acc: 0.7043 - val_loss: 0.6181 - val_acc: 0.6744 - lr: 0.0010
# Epoch 4/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.5607 - acc: 0.7271
# Epoch 4: val_loss did not improve from 0.61686
# 242/242 [==============================] - 31s 127ms/step - loss: 0.5608 - acc: 0.7271 - val_loss: 0.6246 - val_acc: 0.6753 - lr: 0.0010
# Epoch 5/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.5315 - acc: 0.7481
# Epoch 5: val_loss did not improve from 0.61686
# 242/242 [==============================] - 31s 127ms/step - loss: 0.5315 - acc: 0.7481 - val_loss: 0.6237 - val_acc: 0.6767 - lr: 2.0000e-04
# Epoch 6/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.5239 - acc: 0.7530
# Epoch 6: val_loss did not improve from 0.61686
# 242/242 [==============================] - 31s 127ms/step - loss: 0.5239 - acc: 0.7530 - val_loss: 0.6266 - val_acc: 0.6753 - lr: 2.0000e-04
# Epoch 7/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.5180 - acc: 0.7567
# Epoch 7: val_loss did not improve from 0.61686
# 242/242 [==============================] - 31s 127ms/step - loss: 0.5181 - acc: 0.7567 - val_loss: 0.6274 - val_acc: 0.6749 - lr: 4.0000e-05
# 138/138 [==============================] - 2s 14ms/step
# AUC:  0.6925303344999227 AUPRC:  0.63581186691555 F1:  0.57395269307495
# 138/138 [==============================] - 2s 14ms/step
# 0.6953339600310808 0.6395073716351842 0.6498975643068519 0.5746681415929203
# Problem type:  los_7
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.2863 - acc: 0.9182
# Epoch 1: val_loss improved from inf to 0.26291, saving model to 64-basiccnn1d-word2vec-los_7-best_model.hdf5
# 242/242 [==============================] - 33s 128ms/step - loss: 0.2861 - acc: 0.9183 - val_loss: 0.2629 - val_acc: 0.9238 - lr: 0.0010
# Epoch 2/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.2458 - acc: 0.9223
# Epoch 2: val_loss improved from 0.26291 to 0.25808, saving model to 64-basiccnn1d-word2vec-los_7-best_model.hdf5
# 242/242 [==============================] - 31s 127ms/step - loss: 0.2457 - acc: 0.9223 - val_loss: 0.2581 - val_acc: 0.9238 - lr: 0.0010
# Epoch 3/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.2278 - acc: 0.9236
# Epoch 3: val_loss improved from 0.25808 to 0.25748, saving model to 64-basiccnn1d-word2vec-los_7-best_model.hdf5
# 242/242 [==============================] - 31s 127ms/step - loss: 0.2278 - acc: 0.9236 - val_loss: 0.2575 - val_acc: 0.9234 - lr: 0.0010
# Epoch 4/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.2122 - acc: 0.9261
# Epoch 4: val_loss did not improve from 0.25748
# 242/242 [==============================] - 31s 127ms/step - loss: 0.2121 - acc: 0.9262 - val_loss: 0.2668 - val_acc: 0.9216 - lr: 0.0010
# Epoch 5/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.1947 - acc: 0.9308
# Epoch 5: val_loss did not improve from 0.25748
# 242/242 [==============================] - 31s 127ms/step - loss: 0.1948 - acc: 0.9308 - val_loss: 0.2720 - val_acc: 0.9188 - lr: 0.0010
# Epoch 6/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.1759 - acc: 0.9378
# Epoch 6: val_loss did not improve from 0.25748
# 242/242 [==============================] - 31s 128ms/step - loss: 0.1762 - acc: 0.9378 - val_loss: 0.2768 - val_acc: 0.9197 - lr: 2.0000e-04
# Epoch 7/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.1718 - acc: 0.9394
# Epoch 7: val_loss did not improve from 0.25748
# 242/242 [==============================] - 31s 128ms/step - loss: 0.1717 - acc: 0.9395 - val_loss: 0.2812 - val_acc: 0.9193 - lr: 2.0000e-04
# Epoch 8/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.1676 - acc: 0.9404
# Epoch 8: val_loss did not improve from 0.25748
# 242/242 [==============================] - 31s 127ms/step - loss: 0.1676 - acc: 0.9403 - val_loss: 0.2817 - val_acc: 0.9193 - lr: 4.0000e-05
# 138/138 [==============================] - 2s 14ms/step
# AUC:  0.69748273542005 AUPRC:  0.19031596282842955 F1:  0.09313725490196079
# 138/138 [==============================] - 2s 14ms/step
# 0.720532715627155 0.2050350613924397 0.9196448895970862 0.011204481792717089
# Iteration number:  5
# Problem type:  mort_hosp
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.2759 - acc: 0.9043
# Epoch 1: val_loss improved from inf to 0.24094, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# 242/242 [==============================] - 33s 130ms/step - loss: 0.2759 - acc: 0.9043 - val_loss: 0.2409 - val_acc: 0.9152 - lr: 0.0010
# Epoch 2/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.2173 - acc: 0.9211
# Epoch 2: val_loss improved from 0.24094 to 0.23365, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# 242/242 [==============================] - 31s 129ms/step - loss: 0.2174 - acc: 0.9211 - val_loss: 0.2337 - val_acc: 0.9156 - lr: 0.0010
# Epoch 3/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.1909 - acc: 0.9289
# Epoch 3: val_loss did not improve from 0.23365
# 242/242 [==============================] - 31s 129ms/step - loss: 0.1909 - acc: 0.9288 - val_loss: 0.2392 - val_acc: 0.9161 - lr: 0.0010
# Epoch 4/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.1681 - acc: 0.9381
# Epoch 4: val_loss did not improve from 0.23365
# 242/242 [==============================] - 31s 129ms/step - loss: 0.1680 - acc: 0.9381 - val_loss: 0.2458 - val_acc: 0.9147 - lr: 0.0010
# Epoch 5/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.1456 - acc: 0.9483
# Epoch 5: val_loss did not improve from 0.23365
# 242/242 [==============================] - 31s 129ms/step - loss: 0.1457 - acc: 0.9482 - val_loss: 0.2492 - val_acc: 0.9129 - lr: 2.0000e-04
# Epoch 6/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.1397 - acc: 0.9505
# Epoch 6: val_loss did not improve from 0.23365
# 242/242 [==============================] - 31s 129ms/step - loss: 0.1398 - acc: 0.9505 - val_loss: 0.2548 - val_acc: 0.9120 - lr: 2.0000e-04
# Epoch 7/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.1358 - acc: 0.9529
# Epoch 7: val_loss did not improve from 0.23365
# 242/242 [==============================] - 31s 129ms/step - loss: 0.1359 - acc: 0.9528 - val_loss: 0.2554 - val_acc: 0.9106 - lr: 4.0000e-05
# 138/138 [==============================] - 2s 14ms/step
# AUC:  0.8741730792980477 AUPRC:  0.5546345610718507 F1:  0.47375504710632577
# 138/138 [==============================] - 2s 14ms/step
# 0.8831622387542609 0.5784335482914326 0.9148645572501707 0.4776536312849163
# Problem type:  mort_icu
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.2229 - acc: 0.9327
# Epoch 1: val_loss improved from inf to 0.17794, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# 242/242 [==============================] - 33s 130ms/step - loss: 0.2231 - acc: 0.9326 - val_loss: 0.1779 - val_acc: 0.9439 - lr: 0.0010
# Epoch 2/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.1589 - acc: 0.9483
# Epoch 2: val_loss improved from 0.17794 to 0.17112, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# 242/242 [==============================] - 31s 127ms/step - loss: 0.1588 - acc: 0.9484 - val_loss: 0.1711 - val_acc: 0.9421 - lr: 0.0010
# Epoch 3/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.1368 - acc: 0.9529
# Epoch 3: val_loss did not improve from 0.17112
# 242/242 [==============================] - 31s 127ms/step - loss: 0.1367 - acc: 0.9530 - val_loss: 0.1738 - val_acc: 0.9421 - lr: 0.0010
# Epoch 4/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.1177 - acc: 0.9617
# Epoch 4: val_loss did not improve from 0.17112
# 242/242 [==============================] - 31s 127ms/step - loss: 0.1177 - acc: 0.9617 - val_loss: 0.1800 - val_acc: 0.9403 - lr: 0.0010
# Epoch 5/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0986 - acc: 0.9688
# Epoch 5: val_loss did not improve from 0.17112
# 242/242 [==============================] - 31s 127ms/step - loss: 0.0986 - acc: 0.9688 - val_loss: 0.1795 - val_acc: 0.9416 - lr: 2.0000e-04
# Epoch 6/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0946 - acc: 0.9699
# Epoch 6: val_loss did not improve from 0.17112
# 242/242 [==============================] - 31s 127ms/step - loss: 0.0946 - acc: 0.9699 - val_loss: 0.1820 - val_acc: 0.9421 - lr: 2.0000e-04
# Epoch 7/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0911 - acc: 0.9719
# Epoch 7: val_loss did not improve from 0.17112
# 242/242 [==============================] - 31s 128ms/step - loss: 0.0910 - acc: 0.9720 - val_loss: 0.1824 - val_acc: 0.9421 - lr: 4.0000e-05
# 138/138 [==============================] - 2s 14ms/step
# AUC:  0.877377214035537 AUPRC:  0.512514501388341 F1:  0.47294589178356716
# 138/138 [==============================] - 2s 14ms/step
# 0.8850973527606836 0.5152318754414935 0.9424083769633508 0.4314606741573033
# Problem type:  los_3
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.6644 - acc: 0.6334
# Epoch 1: val_loss improved from inf to 0.62117, saving model to 64-basiccnn1d-word2vec-los_3-best_model.hdf5
# 242/242 [==============================] - 33s 129ms/step - loss: 0.6645 - acc: 0.6333 - val_loss: 0.6212 - val_acc: 0.6772 - lr: 0.0010
# Epoch 2/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.6145 - acc: 0.6776
# Epoch 2: val_loss improved from 0.62117 to 0.61574, saving model to 64-basiccnn1d-word2vec-los_3-best_model.hdf5
# 242/242 [==============================] - 31s 128ms/step - loss: 0.6145 - acc: 0.6776 - val_loss: 0.6157 - val_acc: 0.6762 - lr: 0.0010
# Epoch 3/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.5882 - acc: 0.7003
# Epoch 3: val_loss did not improve from 0.61574
# 242/242 [==============================] - 31s 128ms/step - loss: 0.5882 - acc: 0.7004 - val_loss: 0.6249 - val_acc: 0.6685 - lr: 0.0010
# Epoch 4/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.5617 - acc: 0.7218
# Epoch 4: val_loss did not improve from 0.61574
# 242/242 [==============================] - 31s 127ms/step - loss: 0.5619 - acc: 0.7217 - val_loss: 0.6209 - val_acc: 0.6712 - lr: 0.0010
# Epoch 5/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.5309 - acc: 0.7486
# Epoch 5: val_loss did not improve from 0.61574
# ...
# Epoch 6/100
# 242/242 [==============================] - ETA: 0s - loss: 0.0773 - acc: 0.9760
# Epoch 6: val_loss did not improve from 0.17131
# 242/242 [==============================] - 45s 184ms/step - loss: 0.0773 - acc: 0.9760 - val_loss: 0.1880 - val_acc: 0.9389 - lr: 2.0000e-04
# Epoch 7/100
# 242/242 [==============================] - ETA: 0s - loss: 0.0741 - acc: 0.9768
# Epoch 7: val_loss did not improve from 0.17131
# 242/242 [==============================] - 45s 184ms/step - loss: 0.0741 - acc: 0.9768 - val_loss: 0.1884 - val_acc: 0.9384 - lr: 4.0000e-05
# 138/138 [==============================] - 3s 17ms/step
# AUC:  0.8745836606012152 AUPRC:  0.5026287434083422 F1:  0.4489795918367347
# 138/138 [==============================] - 2s 17ms/step
# 0.8812704656286744 0.5160808098907378 0.938993853858411 0.4508196721311476
# Problem type:  los_3
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 242/242 [==============================] - ETA: 0s - loss: 0.6746 - acc: 0.6247
# Epoch 1: val_loss improved from inf to 0.62353, saving model to 64-basiccnn1d-concat-los_3-best_model.hdf5
# 242/242 [==============================] - 47s 186ms/step - loss: 0.6746 - acc: 0.6247 - val_loss: 0.6235 - val_acc: 0.6653 - lr: 0.0010
# Epoch 2/100
# 242/242 [==============================] - ETA: 0s - loss: 0.6142 - acc: 0.6811
# Epoch 2: val_loss improved from 0.62353 to 0.61903, saving model to 64-basiccnn1d-concat-los_3-best_model.hdf5
# 242/242 [==============================] - 45s 186ms/step - loss: 0.6142 - acc: 0.6811 - val_loss: 0.6190 - val_acc: 0.6676 - lr: 0.0010
# Epoch 3/100
# 242/242 [==============================] - ETA: 0s - loss: 0.5857 - acc: 0.7059
# Epoch 3: val_loss improved from 0.61903 to 0.61708, saving model to 64-basiccnn1d-concat-los_3-best_model.hdf5
# 242/242 [==============================] - 45s 185ms/step - loss: 0.5857 - acc: 0.7059 - val_loss: 0.6171 - val_acc: 0.6671 - lr: 0.0010
# Epoch 4/100
# 242/242 [==============================] - ETA: 0s - loss: 0.5569 - acc: 0.7274
# Epoch 4: val_loss did not improve from 0.61708
# 242/242 [==============================] - 45s 185ms/step - loss: 0.5569 - acc: 0.7274 - val_loss: 0.6273 - val_acc: 0.6644 - lr: 0.0010
# Epoch 5/100
# 242/242 [==============================] - ETA: 0s - loss: 0.5278 - acc: 0.7486
# Epoch 5: val_loss did not improve from 0.61708
# 242/242 [==============================] - 45s 185ms/step - loss: 0.5278 - acc: 0.7486 - val_loss: 0.6357 - val_acc: 0.6735 - lr: 0.0010
# Epoch 6/100
# 242/242 [==============================] - ETA: 0s - loss: 0.4928 - acc: 0.7766
# Epoch 6: val_loss did not improve from 0.61708
# 242/242 [==============================] - 45s 185ms/step - loss: 0.4928 - acc: 0.7766 - val_loss: 0.6379 - val_acc: 0.6717 - lr: 2.0000e-04
# Epoch 7/100
# 242/242 [==============================] - ETA: 0s - loss: 0.4848 - acc: 0.7811
# Epoch 7: val_loss did not improve from 0.61708
# 242/242 [==============================] - 45s 185ms/step - loss: 0.4848 - acc: 0.7811 - val_loss: 0.6427 - val_acc: 0.6689 - lr: 2.0000e-04
# Epoch 8/100
# 242/242 [==============================] - ETA: 0s - loss: 0.4788 - acc: 0.7854
# Epoch 8: val_loss did not improve from 0.61708
# 242/242 [==============================] - 45s 187ms/step - loss: 0.4788 - acc: 0.7854 - val_loss: 0.6428 - val_acc: 0.6712 - lr: 4.0000e-05
# 138/138 [==============================] - 3s 17ms/step
# AUC:  0.6853816398732206 AUPRC:  0.629303599065296 F1:  0.5687553161326906
# 138/138 [==============================] - 2s 17ms/step
# 0.6925732082478505 0.6388610206579415 0.6615069428636468 0.5354576694782881
# Problem type:  los_7
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 242/242 [==============================] - ETA: 0s - loss: 0.2971 - acc: 0.9183
# Epoch 1: val_loss improved from inf to 0.26403, saving model to 64-basiccnn1d-concat-los_7-best_model.hdf5
# 242/242 [==============================] - 47s 186ms/step - loss: 0.2971 - acc: 0.9183 - val_loss: 0.2640 - val_acc: 0.9238 - lr: 0.0010
# Epoch 2/100
# 242/242 [==============================] - ETA: 0s - loss: 0.2463 - acc: 0.9222
# Epoch 2: val_loss did not improve from 0.26403
# 242/242 [==============================] - 45s 185ms/step - loss: 0.2463 - acc: 0.9222 - val_loss: 0.2674 - val_acc: 0.9238 - lr: 0.0010
# Epoch 3/100
# 242/242 [==============================] - ETA: 0s - loss: 0.2260 - acc: 0.9239
# Epoch 3: val_loss did not improve from 0.26403
# 242/242 [==============================] - 45s 185ms/step - loss: 0.2260 - acc: 0.9239 - val_loss: 0.2671 - val_acc: 0.9238 - lr: 0.0010
# Epoch 4/100
# 242/242 [==============================] - ETA: 0s - loss: 0.2056 - acc: 0.9277
# Epoch 4: val_loss did not improve from 0.26403
# 242/242 [==============================] - 45s 185ms/step - loss: 0.2056 - acc: 0.9277 - val_loss: 0.2684 - val_acc: 0.9234 - lr: 2.0000e-04
# Epoch 5/100
# 242/242 [==============================] - ETA: 0s - loss: 0.2015 - acc: 0.9295
# Epoch 5: val_loss did not improve from 0.26403
# 242/242 [==============================] - 45s 185ms/step - loss: 0.2015 - acc: 0.9295 - val_loss: 0.2690 - val_acc: 0.9216 - lr: 2.0000e-04
# Epoch 6/100
# 242/242 [==============================] - ETA: 0s - loss: 0.1978 - acc: 0.9304
# Epoch 6: val_loss did not improve from 0.26403
# 242/242 [==============================] - 45s 186ms/step - loss: 0.1978 - acc: 0.9304 - val_loss: 0.2697 - val_acc: 0.9225 - lr: 4.0000e-05
# 138/138 [==============================] - 3s 17ms/step
# AUC:  0.7123959474222377 AUPRC:  0.20722579562373025 F1:  0.07772020725388601
# 138/138 [==============================] - 2s 17ms/step
# 0.7130638702033703 0.18541219818777044 0.9196448895970862 0.005633802816901409
# Iteration number:  10
# Problem type:  mort_hosp
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 242/242 [==============================] - ETA: 0s - loss: 0.2814 - acc: 0.9069
# Epoch 1: val_loss improved from inf to 0.23595, saving model to 64-basiccnn1d-concat-mort_hosp-best_model.hdf5
# 242/242 [==============================] - 46s 186ms/step - loss: 0.2814 - acc: 0.9069 - val_loss: 0.2360 - val_acc: 0.9138 - lr: 0.0010
# Epoch 2/100
# 242/242 [==============================] - ETA: 0s - loss: 0.2176 - acc: 0.9230
# Epoch 2: val_loss did not improve from 0.23595
# 242/242 [==============================] - 44s 184ms/step - loss: 0.2176 - acc: 0.9230 - val_loss: 0.2364 - val_acc: 0.9147 - lr: 0.0010
# Epoch 3/100
# 242/242 [==============================] - ETA: 0s - loss: 0.1892 - acc: 0.9331
# Epoch 3: val_loss did not improve from 0.23595
# 242/242 [==============================] - 44s 184ms/step - loss: 0.1892 - acc: 0.9331 - val_loss: 0.2394 - val_acc: 0.9179 - lr: 0.0010
# Epoch 4/100
# 242/242 [==============================] - ETA: 0s - loss: 0.1615 - acc: 0.9444
# Epoch 4: val_loss did not improve from 0.23595
# 242/242 [==============================] - 45s 184ms/step - loss: 0.1615 - acc: 0.9444 - val_loss: 0.2413 - val_acc: 0.9143 - lr: 2.0000e-04
# Epoch 5/100
# 242/242 [==============================] - ETA: 0s - loss: 0.1563 - acc: 0.9464
# Epoch 5: val_loss did not improve from 0.23595
# 242/242 [==============================] - 45s 184ms/step - loss: 0.1563 - acc: 0.9464 - val_loss: 0.2431 - val_acc: 0.9152 - lr: 2.0000e-04
# Epoch 6/100
# 242/242 [==============================] - ETA: 0s - loss: 0.1508 - acc: 0.9476
# Epoch 6: val_loss did not improve from 0.23595
# 242/242 [==============================] - 45s 185ms/step - loss: 0.1508 - acc: 0.9476 - val_loss: 0.2433 - val_acc: 0.9152 - lr: 4.0000e-05
# 138/138 [==============================] - 3s 17ms/step
# AUC:  0.8714162215803215 AUPRC:  0.552988307020003 F1:  0.4628330995792427
# 138/138 [==============================] - 2s 18ms/step
# 0.8756583398088069 0.5643169582537746 0.9166856362394719 0.43343653250774
# Problem type:  mort_icu
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 242/242 [==============================] - ETA: 0s - loss: 0.2159 - acc: 0.9337
# Epoch 1: val_loss improved from inf to 0.17479, saving model to 64-basiccnn1d-concat-mort_icu-best_model.hdf5
# 242/242 [==============================] - 47s 187ms/step - loss: 0.2159 - acc: 0.9337 - val_loss: 0.1748 - val_acc: 0.9416 - lr: 0.0010
# Epoch 2/100
# 242/242 [==============================] - ETA: 0s - loss: 0.1578 - acc: 0.9460
# Epoch 2: val_loss improved from 0.17479 to 0.16884, saving model to 64-basiccnn1d-concat-mort_icu-best_model.hdf5
# 242/242 [==============================] - 45s 186ms/step - loss: 0.1578 - acc: 0.9460 - val_loss: 0.1688 - val_acc: 0.9435 - lr: 0.0010
# Epoch 3/100
# 242/242 [==============================] - ETA: 0s - loss: 0.1329 - acc: 0.9553
# Epoch 3: val_loss did not improve from 0.16884
# 242/242 [==============================] - 45s 186ms/step - loss: 0.1329 - acc: 0.9553 - val_loss: 0.1709 - val_acc: 0.9403 - lr: 0.0010
# Epoch 4/100
# 242/242 [==============================] - ETA: 0s - loss: 0.1131 - acc: 0.9613
# Epoch 4: val_loss did not improve from 0.16884
# 242/242 [==============================] - 45s 186ms/step - loss: 0.1131 - acc: 0.9613 - val_loss: 0.1768 - val_acc: 0.9407 - lr: 0.0010
# Epoch 5/100
# 242/242 [==============================] - ETA: 0s - loss: 0.0934 - acc: 0.9685
# Epoch 5: val_loss did not improve from 0.16884
# 242/242 [==============================] - 45s 186ms/step - loss: 0.0934 - acc: 0.9685 - val_loss: 0.1819 - val_acc: 0.9389 - lr: 2.0000e-04
# Epoch 6/100
# 242/242 [==============================] - ETA: 0s - loss: 0.0880 - acc: 0.9713
# Epoch 6: val_loss did not improve from 0.16884
# 242/242 [==============================] - 45s 186ms/step - loss: 0.0880 - acc: 0.9713 - val_loss: 0.1865 - val_acc: 0.9389 - lr: 2.0000e-04
# Epoch 7/100
# 242/242 [==============================] - ETA: 0s - loss: 0.0849 - acc: 0.9720
# Epoch 7: val_loss did not improve from 0.16884
# 242/242 [==============================] - 45s 186ms/step - loss: 0.0849 - acc: 0.9720 - val_loss: 0.1868 - val_acc: 0.9380 - lr: 4.0000e-05
# 138/138 [==============================] - 3s 17ms/step
# AUC:  0.8708157207258556 AUPRC:  0.48162393767810463 F1:  0.444
# 138/138 [==============================] - 2s 17ms/step
# 0.8838411125494415 0.5033378922179601 0.9414978374687002 0.417233560090703
# Problem type:  los_3
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 242/242 [==============================] - ETA: 0s - loss: 0.6804 - acc: 0.6295
# Epoch 1: val_loss improved from inf to 0.62073, saving model to 64-basiccnn1d-concat-los_3-best_model.hdf5
# 242/242 [==============================] - 46s 186ms/step - loss: 0.6804 - acc: 0.6295 - val_loss: 0.6207 - val_acc: 0.6808 - lr: 0.0010
# Epoch 2/100
# 242/242 [==============================] - ETA: 0s - loss: 0.6177 - acc: 0.6734
# Epoch 2: val_loss improved from 0.62073 to 0.62071, saving model to 64-basiccnn1d-concat-los_3-best_model.hdf5
# 242/242 [==============================] - 45s 185ms/step - loss: 0.6177 - acc: 0.6734 - val_loss: 0.6207 - val_acc: 0.6781 - lr: 0.0010
# Epoch 3/100
# 242/242 [==============================] - ETA: 0s - loss: 0.5890 - acc: 0.7012
# Epoch 3: val_loss did not improve from 0.62071
# 242/242 [==============================] - 45s 184ms/step - loss: 0.5890 - acc: 0.7012 - val_loss: 0.6218 - val_acc: 0.6676 - lr: 0.0010
# Epoch 4/100
# 242/242 [==============================] - ETA: 0s - loss: 0.5589 - acc: 0.7267
# Epoch 4: val_loss improved from 0.62071 to 0.62012, saving model to 64-basiccnn1d-concat-los_3-best_model.hdf5
# 242/242 [==============================] - 45s 185ms/step - loss: 0.5589 - acc: 0.7267 - val_loss: 0.6201 - val_acc: 0.6744 - lr: 2.0000e-04
# Epoch 5/100
# 242/242 [==============================] - ETA: 0s - loss: 0.5504 - acc: 0.7335
# Epoch 5: val_loss did not improve from 0.62012
# 242/242 [==============================] - 45s 184ms/step - loss: 0.5504 - acc: 0.7335 - val_loss: 0.6232 - val_acc: 0.6726 - lr: 2.0000e-04
# Epoch 6/100
# 242/242 [==============================] - ETA: 0s - loss: 0.5450 - acc: 0.7390
# Epoch 6: val_loss did not improve from 0.62012
# 242/242 [==============================] - 45s 184ms/step - loss: 0.5450 - acc: 0.7390 - val_loss: 0.6231 - val_acc: 0.6726 - lr: 2.0000e-04
# Epoch 7/100
# 242/242 [==============================] - ETA: 0s - loss: 0.5397 - acc: 0.7411
# Epoch 7: val_loss did not improve from 0.62012
# 242/242 [==============================] - 45s 184ms/step - loss: 0.5397 - acc: 0.7411 - val_loss: 0.6233 - val_acc: 0.6726 - lr: 4.0000e-05
# Epoch 8/100
# 242/242 [==============================] - ETA: 0s - loss: 0.5392 - acc: 0.7407
# Epoch 8: val_loss did not improve from 0.62012
# 242/242 [==============================] - 45s 186ms/step - loss: 0.5392 - acc: 0.7407 - val_loss: 0.6235 - val_acc: 0.6717 - lr: 4.0000e-05
# Epoch 9/100
# 242/242 [==============================] - ETA: 0s - loss: 0.5379 - acc: 0.7469
# Epoch 9: val_loss did not improve from 0.62012
# 242/242 [==============================] - 45s 184ms/step - loss: 0.5379 - acc: 0.7469 - val_loss: 0.6236 - val_acc: 0.6717 - lr: 1.0000e-05
# 138/138 [==============================] - 3s 17ms/step
# AUC:  0.7000992977174229 AUPRC:  0.6402545798469417 F1:  0.5720876585928489
# 138/138 [==============================] - 2s 17ms/step
# 0.7019205321849521 0.6426242489493372 0.6678807193262007 0.5755018911841723
# Problem type:  los_7
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 242/242 [==============================] - ETA: 0s - loss: 0.2915 - acc: 0.9204
# Epoch 1: val_loss improved from inf to 0.26171, saving model to 64-basiccnn1d-concat-los_7-best_model.hdf5
# 242/242 [==============================] - 46s 185ms/step - loss: 0.2915 - acc: 0.9204 - val_loss: 0.2617 - val_acc: 0.9238 - lr: 0.0010
# Epoch 2/100
# 242/242 [==============================] - ETA: 0s - loss: 0.2452 - acc: 0.9227
# Epoch 2: val_loss improved from 0.26171 to 0.26134, saving model to 64-basiccnn1d-concat-los_7-best_model.hdf5
# 242/242 [==============================] - 45s 184ms/step - loss: 0.2452 - acc: 0.9227 - val_loss: 0.2613 - val_acc: 0.9238 - lr: 0.0010
# Epoch 3/100
# 242/242 [==============================] - ETA: 0s - loss: 0.2237 - acc: 0.9237
# Epoch 3: val_loss did not improve from 0.26134
# 242/242 [==============================] - 45s 184ms/step - loss: 0.2237 - acc: 0.9237 - val_loss: 0.2657 - val_acc: 0.9202 - lr: 0.0010
# Epoch 4/100
# 242/242 [==============================] - ETA: 0s - loss: 0.2029 - acc: 0.9282
# Epoch 4: val_loss did not improve from 0.26134
# 242/242 [==============================] - 45s 184ms/step - loss: 0.2029 - acc: 0.9282 - val_loss: 0.2719 - val_acc: 0.9216 - lr: 0.0010
# Epoch 5/100
# 242/242 [==============================] - ETA: 0s - loss: 0.1798 - acc: 0.9363
# Epoch 5: val_loss did not improve from 0.26134
# 242/242 [==============================] - 45s 184ms/step - loss: 0.1798 - acc: 0.9363 - val_loss: 0.2772 - val_acc: 0.9193 - lr: 2.0000e-04
# Epoch 6/100
# 242/242 [==============================] - ETA: 0s - loss: 0.1733 - acc: 0.9384
# Epoch 6: val_loss did not improve from 0.26134
# 242/242 [==============================] - 45s 185ms/step - loss: 0.1733 - acc: 0.9384 - val_loss: 0.2796 - val_acc: 0.9197 - lr: 2.0000e-04
# Epoch 7/100
# 242/242 [==============================] - ETA: 0s - loss: 0.1698 - acc: 0.9401
# Epoch 7: val_loss did not improve from 0.26134
# 242/242 [==============================] - 45s 185ms/step - loss: 0.1698 - acc: 0.9401 - val_loss: 0.2810 - val_acc: 0.9197 - lr: 4.0000e-05
# 138/138 [==============================] - 3s 17ms/step
# AUC:  0.7136660497997631 AUPRC:  0.20307216514835907 F1:  0.09852216748768473
# 138/138 [==============================] - 2s 17ms/step
# 0.721089434510696 0.20976761534105168 0.9196448895970862 0.005633802816901409
