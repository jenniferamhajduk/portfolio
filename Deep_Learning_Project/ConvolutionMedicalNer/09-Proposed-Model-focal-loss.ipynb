# %%
import pandas as pd
import os
import numpy as np
from gensim.models import Word2Vec, FastText
#import glove
#from glove import Corpus
os.environ['KERAS_BACKEND'] = 'tensorflow'

import collections
import gc 

import keras
from keras import backend as K
from keras import regularizers
from keras.models import Sequential, Model
from keras.layers import Flatten, Dense, Dropout, Input, concatenate, Activation, Concatenate, LSTM, GRU
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, Conv1D, BatchNormalization, GRU, Convolution1D, LSTM
from keras.layers import UpSampling1D, MaxPooling1D, GlobalMaxPooling1D, GlobalAveragePooling1D,MaxPool1D
from keras.initializers import GlorotUniform


from keras.optimizers import Adam

from keras.callbacks import EarlyStopping, ModelCheckpoint, History, ReduceLROnPlateau
from keras.utils import np_utils
#from keras.backend.tensorflow_backend import set_session, clear_session, get_session
import tensorflow as tf


from sklearn.utils import class_weight
from sklearn.metrics import average_precision_score, roc_auc_score, accuracy_score, f1_score

import warnings
warnings.filterwarnings('ignore')

# %%
type_of_ner = "new"

x_train_lstm = pd.read_pickle("data/"+type_of_ner+"_x_train.pkl")
x_dev_lstm = pd.read_pickle("data/"+type_of_ner+"_x_dev.pkl")
x_test_lstm = pd.read_pickle("data/"+type_of_ner+"_x_test.pkl")

y_train = pd.read_pickle("data/"+type_of_ner+"_y_train.pkl")
y_dev = pd.read_pickle("data/"+type_of_ner+"_y_dev.pkl")
y_test = pd.read_pickle("data/"+type_of_ner+"_y_test.pkl")


ner_word2vec = pd.read_pickle("data/"+type_of_ner+"_ner_word2vec_limited_dict.pkl")
ner_fasttext = pd.read_pickle("data/"+type_of_ner+"_ner_fasttext_limited_dict.pkl")
ner_concat = pd.read_pickle("data/"+type_of_ner+"_ner_combined_limited_dict.pkl")

train_ids = pd.read_pickle("data/"+type_of_ner+"_train_ids.pkl")
dev_ids = pd.read_pickle("data/"+type_of_ner+"_dev_ids.pkl")
test_ids = pd.read_pickle("data/"+type_of_ner+"_test_ids.pkl")

# %%
def focal_loss(gamma=2., alpha=.25):
    def focal_loss_fixed(y_true, y_pred):
        pt_1 = tf.where(tf.equal(y_true, tf.cast(1, dtype=y_true.dtype)), y_pred, tf.ones_like(y_pred))
        pt_0 = tf.where(tf.equal(y_true, tf.cast(0, dtype=y_true.dtype)), y_pred, tf.zeros_like(y_pred))
        return -tf.keras.backend.mean(alpha * tf.keras.backend.pow(1. - pt_1, gamma) * tf.keras.backend.log(pt_1)) - tf.keras.backend.mean((1 - alpha) * tf.keras.backend.pow(pt_0, gamma) * tf.keras.backend.log(1. - pt_0))
    return focal_loss_fixed


def create_dataset(dict_of_ner):
    temp_data = []
    for k, v in sorted(dict_of_ner.items()):
        temp = []
        for embed in v:
            temp.append(embed)
        temp_data.append(np.mean(temp, axis = 0)) 
    return np.asarray(temp_data)

def make_prediction_cnn(model, test_data):
    probs = model.predict(test_data)
    y_pred = [1 if i>=0.5 else 0 for i in probs]
    return probs, y_pred

def save_scores_cnn(predictions, probs, ground_truth, 
                          
                          embed_name, problem_type, iteration, hidden_unit_size,
                          
                          sequence_name, type_of_ner):
    
    auc = roc_auc_score(ground_truth, probs)
    auprc = average_precision_score(ground_truth, probs)
    acc   = accuracy_score(ground_truth, predictions)
    F1    = f1_score(ground_truth, predictions)
    
    result_dict = {}    
    result_dict['auc'] = auc
    result_dict['auprc'] = auprc
    result_dict['acc'] = acc
    result_dict['F1'] = F1

    result_path = "results/cnn/"
    file_name = str(sequence_name)+"-"+str(hidden_unit_size)+"-"+embed_name
    file_name = file_name +"-"+problem_type+"-"+str(iteration)+"-"+type_of_ner+"-cnn-.p"
    pd.to_pickle(result_dict, os.path.join(result_path, file_name))

    print(auc, auprc, acc, F1)
    
def print_scores_cnn(predictions, probs, ground_truth, model_name, problem_type, iteration, hidden_unit_size):
    auc = roc_auc_score(ground_truth, probs)
    auprc = average_precision_score(ground_truth, probs)
    acc   = accuracy_score(ground_truth, predictions)
    F1    = f1_score(ground_truth, predictions)
    
    print ("AUC: ", auc, "AUPRC: ", auprc, "F1: ", F1)
    
def get_subvector_data(size, embed_name, data):
    if embed_name == "concat":
        vector_size = 200
    else:
        vector_size = 100

    x_data = {}
    for k, v in data.items():
        number_of_additional_vector = len(v) - size
        vector = []
        for i in v:
            vector.append(i)
        if number_of_additional_vector < 0: 
            number_of_additional_vector = np.abs(number_of_additional_vector)

            temp = vector[:size]
            for i in range(0, number_of_additional_vector):
                temp.append(np.zeros(vector_size))
            x_data[k] = np.asarray(temp)
        else:
            x_data[k] = np.asarray(vector[:size])

    return x_data


def proposedmodel(layer_name, number_of_unit, embedding_name, ner_limit, num_filter):
    if embedding_name == "concat":
        input_dimension = 200
    else:
        input_dimension = 100

    sequence_input = Input(shape=(24,104))

    input_img = Input(shape=(ner_limit, input_dimension), name = "cnn_input")

    convs = []
    filter_sizes = [2,3,4]


    text_conv1d = Conv1D(filters=num_filter, kernel_size=3, 
                    padding = 'valid', strides = 1, dilation_rate=1, activation='relu', 
                            kernel_initializer=tf.keras.initializers.GlorotUniform())(input_img)
        
    text_conv1d = Conv1D(filters=num_filter*2, kernel_size=3, 
                    padding = 'valid', strides = 1, dilation_rate=1, activation='relu',
                            kernel_initializer=tf.keras.initializers.GlorotUniform())(text_conv1d)   
        
    text_conv1d = Conv1D(filters=num_filter*3, kernel_size=3, 
                    padding = 'valid', strides = 1, dilation_rate=1, activation='relu',
                            kernel_initializer=tf.keras.initializers.GlorotUniform())(text_conv1d) 

    
    #concat_conv = keras.layers.Concatenate()([text_conv1d, text_conv1d_2, text_conv1d_3])
    text_embeddings = GlobalMaxPooling1D()(text_conv1d)
    #text_embeddings = Dense(128, activation="relu")(text_embeddings)
    
    if layer_name == "GRU":
        x = GRU(number_of_unit)(sequence_input)
    elif layer_name == "LSTM":
        x = LSTM(number_of_unit)(sequence_input)

    concatenated = keras.layers.Concatenate()([x, text_embeddings])
    #concatenated = merge([x, text_embeddings], mode='concat', concat_axis=1)

    concatenated = Dense(512, activation='relu')(concatenated)
    concatenated = Dropout(0.2)(concatenated)
    #concatenated = Dense(256, activation='relu')(concatenated)
    #concatenated = Dense(512, activation='relu')(concatenated)
    
    #concatenated = Dense(512, activation='relu')(concatenated)
    logits_regularizer = tf.keras.regularizers.L2(0.01)
    preds = Dense(1, activation='sigmoid',use_bias=False,
                         kernel_initializer=tf.keras.initializers.GlorotUniform(), 
                  kernel_regularizer=logits_regularizer)(concatenated)
    
    
    
    
    #opt = Adam(lr=1e-4, decay = 0.01)
    
    opt = Adam(lr=1e-3, decay = 0.01) 
    
    #opt = Adam(lr=0.001)

    model = Model(inputs=[sequence_input, input_img], outputs=preds)
    model.compile(loss=focal_loss(gamma=2., alpha=.25),
                  optimizer=opt,
                  metrics=['acc'])
    
    return model

# %%
embedding_types = ['fasttext']
embedding_dict = [ner_word2vec, ner_fasttext, ner_concat]

target_problems = ['mort_hosp', 'mort_icu', 'los_3', 'los_7']

num_epoch = 100
model_patience = 5
monitor_criteria = 'val_loss'
#monitor_criteria = 'val_acc'
batch_size = 64

filter_number = 32
ner_representation_limit = 64
activation_func = "relu"

sequence_model = "GRU"
sequence_hidden_unit = 256

maxiter = 11
for embed_dict, embed_name in zip(embedding_dict, embedding_types):    
    print ("Embedding: ", embed_name)
    print("=============================")
    
    temp_train_ner = dict((k, embed_dict[k]) for k in train_ids)
    tem_dev_ner = dict((k, embed_dict[k]) for k in dev_ids)
    temp_test_ner = dict((k, embed_dict[k]) for k in test_ids)

    x_train_dict = {}
    x_dev_dict = {}
    x_test_dict = {}

    x_train_dict = get_subvector_data(ner_representation_limit, embed_name, temp_train_ner)
    x_dev_dict = get_subvector_data(ner_representation_limit, embed_name, tem_dev_ner)
    x_test_dict = get_subvector_data(ner_representation_limit, embed_name, temp_test_ner)

    x_train_dict_sorted = collections.OrderedDict(sorted(x_train_dict.items()))
    x_dev_dict_sorted = collections.OrderedDict(sorted(x_dev_dict.items()))
    x_test_dict_sorted = collections.OrderedDict(sorted(x_test_dict.items()))

    x_train_ner = tf.constant(np.array(list(x_train_dict_sorted.values())))
    x_dev_ner = tf.constant(np.array(list(x_dev_dict_sorted.values())))
    x_test_ner = tf.constant(np.array(list(x_test_dict_sorted.values())))


    
        
    for iteration in range(1,maxiter):
        print ("Iteration number: ", iteration)
    
        for each_problem in target_problems:
            print ("Problem type: ", each_problem)
            print ("__________________")
            
            
            early_stopping_monitor = EarlyStopping(monitor=monitor_criteria, patience=model_patience)
            
            best_model_name = str(ner_representation_limit)+"-basiccnn1d-"+str(embed_name)+"-"+str(each_problem)+"-"+"best_model.hdf5"
            
            checkpoint = ModelCheckpoint(best_model_name, monitor=monitor_criteria, verbose=1,
                save_best_only=True, mode='min')
            
            reduce_lr = ReduceLROnPlateau(monitor=monitor_criteria, factor=0.2,
                              patience=2, min_lr=0.00001, epsilon=1e-4, mode='min')
            

            callbacks = [early_stopping_monitor, checkpoint, reduce_lr]
            
            #model = textCNN(sequence_model, sequence_hidden_unit, embed_name, ner_representation_limit)
            model = proposedmodel(sequence_model, sequence_hidden_unit, 
                               embed_name, ner_representation_limit,filter_number)
            #print(type(x_train_lstm), type(x_train_ner), type(y_train), type(x_dev_lstm), type(x_dev_ner), type(y_dev))
            model.fit([x_train_lstm, x_train_ner], y_train[each_problem], epochs=num_epoch, verbose=1, 
                      validation_data=([x_dev_lstm,x_dev_ner], y_dev[each_problem]), callbacks=callbacks, batch_size=batch_size)
            
            
            probs, predictions = make_prediction_cnn(model, [x_test_lstm, x_test_ner])
            print_scores_cnn(predictions, probs, y_test[each_problem], embed_name, each_problem, iteration, sequence_hidden_unit)
            
            model.load_weights(best_model_name)
                      
            probs, predictions = make_prediction_cnn(model, [x_test_lstm, x_test_ner])
            save_scores_cnn(predictions, probs, y_test[each_problem], embed_name, each_problem, iteration,
                            sequence_hidden_unit, sequence_model, type_of_ner)
            del model
            K.clear_session()
            gc.collect()
# Out:
# Embedding:  fasttext
# =============================
# Iteration number:  1
# Problem type:  mort_hosp
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0465 - acc: 0.9009
# Epoch 1: val_loss improved from inf to 0.03274, saving model to 64-basiccnn1d-fasttext-mort_hosp-best_model.hdf5
# 242/242 [==============================] - 27s 104ms/step - loss: 0.0465 - acc: 0.9010 - val_loss: 0.0327 - val_acc: 0.9143 - lr: 0.0010
# Epoch 2/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0314 - acc: 0.9109
# Epoch 2: val_loss improved from 0.03274 to 0.03054, saving model to 64-basiccnn1d-fasttext-mort_hosp-best_model.hdf5
# 242/242 [==============================] - 25s 102ms/step - loss: 0.0314 - acc: 0.9107 - val_loss: 0.0305 - val_acc: 0.9156 - lr: 0.0010
# Epoch 3/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0284 - acc: 0.9123
# Epoch 3: val_loss improved from 0.03054 to 0.02897, saving model to 64-basiccnn1d-fasttext-mort_hosp-best_model.hdf5
# 242/242 [==============================] -
# Problem type:  mort_icu
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0343 - acc: 0.9339
# Epoch 1: val_loss improved from inf to 0.02354, saving model to 64-basiccnn1d-fasttext-mort_icu-best_model.hdf5
# 242/242 [==============================] - 28s 109ms/step - loss: 0.0343 - acc: 0.9339 - val_loss: 0.0235 - val_acc: 0.9407 - lr: 0.0010
# Epoch 2/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0222 - acc: 0.9405
# Epoch 2: val_loss improved from 0.02354 to 0.02138, saving model to 64-basiccnn1d-fasttext-mort_icu-best_model.hdf5
# 242/242 [==============================] - 26s 109ms/step - loss: 0.0222 - acc: 0.9405 - val_loss: 0.0214 - val_acc: 0.9421 - lr: 0.0010
# Epoch 3/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0194 - acc: 0.9431
# Epoch 3: val_loss improved from 0.02138 to 0.02000, saving model to 64-basiccnn1d-fasttext-mort_icu-best_model.hdf5
# 242/242 [==============================] - 26s 109ms/step - loss: 0.0195 - acc: 0.9430 - val_loss: 0.0200 - val_acc: 0.9425 - lr: 0.0010
# Epoch 4/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0180 - acc: 0.9435
# Epoch 4: val_loss improved from 0.02000 to 0.01944, saving model to 64-basiccnn1d-fasttext-mort_icu-best_model.hdf5
# 242/242 [==============================] - 26s 108ms/step - loss: 0.0179 - acc: 0.9436 - val_loss: 0.0194 - val_acc: 0.9421 - lr: 0.0010
# Epoch 5/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0168 - acc: 0.9443
# Epoch 5: val_loss improved from 0.01944 to 0.01898, saving model to 64-basiccnn1d-fasttext-mort_icu-best_model.hdf5
# 242/242 [==============================] - 26s 107ms/step - loss: 0.0168 - acc: 0.9444 - val_loss: 0.0190 - val_acc: 0.9425 - lr: 0.0010
# Epoch 6/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0159 - acc: 0.9451
# Epoch 6: val_loss did not improve from 0.01898
# 242/242 [==============================] - 26s 107ms/step - loss: 0.0159 - acc: 0.9451 - val_loss: 0.0190 - val_acc: 0.9421 - lr: 0.0010
# Epoch 7/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0152 - acc: 0.9470
# Epoch 7: val_loss improved from 0.01898 to 0.01860, saving model to 64-basiccnn1d-fasttext-mort_icu-best_model.hdf5
# 242/242 [==============================] - 26s 107ms/step - loss: 0.0152 - acc: 0.9471 - val_loss: 0.0186 - val_acc: 0.9412 - lr: 0.0010
# Epoch 8/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0147 - acc: 0.9470
# Epoch 8: val_loss did not improve from 0.01860
# 242/242 [==============================] - 26s 107ms/step - loss: 0.0147 - acc: 0.9469 - val_loss: 0.0187 - val_acc: 0.9407 - lr: 0.0010
# Epoch 9/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0141 - acc: 0.9484
# Epoch 9: val_loss improved from 0.01860 to 0.01843, saving model to 64-basiccnn1d-fasttext-mort_icu-best_model.hdf5
# 242/242 [==============================] - 26s 107ms/step - loss: 0.0141 - acc: 0.9483 - val_loss: 0.0184 - val_acc: 0.9421 - lr: 0.0010
# Epoch 10/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0136 - acc: 0.9481
# Epoch 10: val_loss improved from 0.01843 to 0.01835, saving model to 64-basiccnn1d-fasttext-mort_icu-best_model.hdf5
# 242/242 [==============================] - 26s 107ms/step - loss: 0.0136 - acc: 0.9482 - val_loss: 0.0184 - val_acc: 0.9412 - lr: 0.0010
# Epoch 11/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0133 - acc: 0.9494
# Epoch 11: val_loss improved from 0.01835 to 0.01833, saving model to 64-basiccnn1d-fasttext-mort_icu-best_model.hdf5
# 242/242 [==============================] - 26s 107ms/step - loss: 0.0133 - acc: 0.9494 - val_loss: 0.0183 - val_acc: 0.9416 - lr: 0.0010
# Epoch 12/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0127 - acc: 0.9494
# Epoch 12: val_loss did not improve from 0.01833
# 242/242 [==============================] - 26s 107ms/step - loss: 0.0127 - acc: 0.9495 - val_loss: 0.0184 - val_acc: 0.9407 - lr: 2.0000e-04
# Epoch 13/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0127 - acc: 0.9496
# Epoch 13: val_loss did not improve from 0.01833
# 242/242 [==============================] - 26s 107ms/step - loss: 0.0127 - acc: 0.9497 - val_loss: 0.0184 - val_acc: 0.9412 - lr: 2.0000e-04
# Epoch 14/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0125 - acc: 0.9501
# Epoch 14: val_loss did not improve from 0.01833
# 242/242 [==============================] - 26s 107ms/step - loss: 0.0125 - acc: 0.9500 - val_loss: 0.0185 - val_acc: 0.9412 - lr: 4.0000e-05
# Epoch 15/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0125 - acc: 0.9504
# Epoch 15: val_loss did not improve from 0.01833
# 242/242 [==============================] - 26s 107ms/step - loss: 0.0125 - acc: 0.9505 - val_loss: 0.0185 - val_acc: 0.9412 - lr: 4.0000e-05
# Epoch 16/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0125 - acc: 0.9510
# Epoch 16: val_loss did not improve from 0.01833
# 242/242 [==============================] - 26s 106ms/step - loss: 0.0125 - acc: 0.9510 - val_loss: 0.0185 - val_acc: 0.9412 - lr: 1.0000e-05
# 138/138 [==============================] - 2s 12ms/step
# AUC:  0.8825715994459739 AUPRC:  0.5223357985226313 F1:  0.30971128608923887
# 138/138 [==============================] - 2s 11ms/step
# 0.8816026783134996 0.5236251183924074 0.9392214887320738 0.2841823056300268
# Problem type:  los_3
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0841 - acc: 0.5967
# Epoch 1: val_loss improved from inf to 0.07154, saving model to 64-basiccnn1d-fasttext-los_3-best_model.hdf5
# 242/242 [==============================] - 28s 110ms/step - loss: 0.0841 - acc: 0.5966 - val_loss: 0.0715 - val_acc: 0.6188 - lr: 0.0010
# Epoch 2/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0706 - acc: 0.6107
# Epoch 2: val_loss improved from 0.07154 to 0.06906, saving model to 64-basiccnn1d-fasttext-los_3-best_model.hdf5
# 242/242 [==============================] - 26s 107ms/step - loss: 0.
# Problem type:  mort_icu
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0349 - acc: 0.9336
# Epoch 1: val_loss improved from inf to 0.02418, saving model to 64-basiccnn1d-fasttext-mort_icu-best_model.hdf5
# 242/242 [==============================] - 28s 110ms/step - loss: 0.0349 - acc: 0.9337 - val_loss: 0.0242 - val_acc: 0.9444 - lr: 0.0010
# Epoch 2/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0220 - acc: 0.9400
# Epoch 2: val_loss improved from 0.02418 to 0.02092, saving model to 64-basiccnn1d-fasttext-mort_icu-best_model.hdf5
# 242/242 [==============================] - 26s 107ms/step - loss: 0.0220 - acc: 0.9400 - val_loss: 0.0209 - val_acc: 0.9421 - lr: 0.0010
# Epoch 3/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0192 - acc: 0.9425
# Epoch 3: val_loss improved from 0.02092 to 0.01988, saving model to 64-basiccnn1d-fasttext-mort_icu-best_model.hdf5
# 242/242 [==============================] - 26s 108ms/step - loss: 0.0192 - acc: 0.9425 - val_loss: 0.0199 - val_acc: 0.9425 - lr: 0.0010
# Epoch 4/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0176 - acc: 0.9425
# Epoch 4: val_loss improved from 0.01988 to 0.01920, saving model to 64-basiccnn1d-fasttext-mort_icu-best_model.hdf5
# 242/242 [==============================] - 26s 108ms/step - loss: 0.0176 - acc: 0.9425 - val_loss: 0.0192 - val_acc: 0.9425 - lr: 0.0010
# Epoch 5/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0164 - acc: 0.9441
# Epoch 5: val_loss improved from 0.01920 to 0.01894, saving model to 64-basiccnn1d-fasttext-mort_icu-best_model.hdf5
# 242/242 [==============================] - 26s 108ms/step - loss: 0.0164 - acc: 0.9441 - val_loss: 0.0189 - val_acc: 0.9439 - lr: 0.0010
# Epoch 6/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0154 - acc: 0.9449
# Epoch 6: val_loss improved from 0.01894 to 0.01841, saving model to 64-basiccnn1d-fasttext-mort_icu-best_model.hdf5
# 242/242 [==============================] - 26s 108ms/step - loss: 0.0154 - acc: 0.9449 - val_loss: 0.0184 - val_acc: 0.9444 - lr: 0.0010
# Epoch 7/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0148 - acc: 0.9457
# Epoch 7: val_loss improved from 0.01841 to 0.01829, saving model to 64-basiccnn1d-fasttext-mort_icu-best_model.hdf5
# 242/242 [==============================] - 26s 108ms/step - loss: 0.0148 - acc: 0.9457 - val_loss: 0.0183 - val_acc: 0.9435 - lr: 0.0010
# Epoch 8/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0141 - acc: 0.9471
# Epoch 8: val_loss improved from 0.01829 to 0.01811, saving model to 64-basiccnn1d-fasttext-mort_icu-best_model.hdf5
# 242/242 [==============================] - 26s 107ms/step - loss: 0.0141 - acc: 0.9471 - val_loss: 0.0181 - val_acc: 0.9444 - lr: 0.0010
# Epoch 9/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0136 - acc: 0.9481
# Epoch 9: val_loss did not improve from 0.01811
# 242/242 [==============================] - 26s 108ms/step - loss: 0.0136 - acc: 0.9481 - val_loss: 0.0181 - val_acc: 0.9425 - lr: 0.0010
# Epoch 10/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0132 - acc: 0.9481
# Epoch 10: val_loss improved from 0.01811 to 0.01803, saving model to 64-basiccnn1d-fasttext-mort_icu-best_model.hdf5
# 242/242 [==============================] - 26s 107ms/step - loss: 0.0132 - acc: 0.9481 - val_loss: 0.0180 - val_acc: 0.9439 - lr: 0.0010
# Epoch 11/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0127 - acc: 0.9495
# Epoch 11: val_loss did not improve from 0.01803
# 242/242 [==============================] - 26s 107ms/step - loss: 0.0127 - acc: 0.9495 - val_loss: 0.0181 - val_acc: 0.9439 - lr: 2.0000e-04
# Epoch 12/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0126 - acc: 0.9496
# Epoch 12: val_loss did not improve from 0.01803
# 242/242 [==============================] - 26s 107ms/step - loss: 0.0126 - acc: 0.9496 - val_loss: 0.0181 - val_acc: 0.9444 - lr: 2.0000e-04
# Epoch 13/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0125 - acc: 0.9512
# Epoch 13: val_loss did not improve from 0.01803
# 242/242 [==============================] - 26s 108ms/step - loss: 0.0125 - acc: 0.9511 - val_loss: 0.0181 - val_acc: 0.9439 - lr: 4.0000e-05
# Epoch 14/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0124 - acc: 0.9508
# Epoch 14: val_loss did not improve from 0.01803
# 242/242 [==============================] - 26s 107ms/step - loss: 0.0124 - acc: 0.9508 - val_loss: 0.0181 - val_acc: 0.9439 - lr: 4.0000e-05
# Epoch 15/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0123 - acc: 0.9509
# Epoch 15: val_loss did not improve from 0.01803
# 242/242 [==============================] - 26s 107ms/step - loss: 0.0123 - acc: 0.9510 - val_loss: 0.0181 - val_acc: 0.9439 - lr: 1.0000e-05
# 138/138 [==============================] - 2s 12ms/step
# AUC:  0.883875465917555 AUPRC:  0.5257290613527857 F1:  0.30158730158730157
# 138/138 [==============================] - 2s 11ms/step
# 0.8836139118648724 0.5263899986565403 0.9385385841110858 0.27419354838709675
# Problem type:  los_3
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0855 - acc: 0.5901
# Epoch 1: val_loss improved from inf to 0.07207, saving model to 64-basiccnn1d-fasttext-los_3-best_model.hdf5
# 242/242 [==============================] - 28s 109ms/step - loss: 0.0855 - acc: 0.5901 - val_loss: 0.0721 - val_acc: 0.6192 - lr: 0.0010
# Epoch 2/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0713 - acc: 0.6078
# Epoch 2: val_loss improved from 0.07207 to 0.07015, saving model to 64-basiccnn1d-fasttext-los_3-best_model.hdf5
# 242/242 [==============================] - 26s 107ms/step - loss: 0.0713 - acc: 0.6078 - val_loss: 0.0702 - val_acc: 0.6133 - lr: 0.0010
# Epoch 3/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0686 - acc: 0.6169
# Epoch 3: val_loss improved from 0.07015 to 0.06893, saving model to 64-basiccnn1d-fasttext-los_3-best_model.hdf5
# 242/242 [==============================] - 26s 107ms/step - loss: 0.0686 - acc: 0.6169 - val_loss: 0.0689 - val_acc: 0.6233 - lr: 0.0010
# Epoch 4/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0669 - acc: 0.6214
# Epoch 4: val_loss improved from 0.06893 to 0.06828, saving model to 64-basiccnn1d-fasttext-los_3-best_model.hdf5
# 242/242 [==============================] - 26s 107ms/step - loss: 0.0669 - acc: 0.6213 - val_loss: 0.0683 - val_acc: 0.6311 - lr: 0.0010
# Epoch 5/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0655 - acc: 0.6279
# Epoch 5: val_loss improved from 0.06828 to 0.06768, saving model to 64-basiccnn1d-fasttext-los_3-best_model.hdf5
# 242/242 [==============================] - 26s 107ms/step - loss: 0.0655 - acc: 0.6278 - val_loss: 0.0677 - val_acc: 0.6293 - lr: 0.0010
# Epoch 6/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0647 - acc: 0.6317
# Epoch 6: val_loss improved from 0.06768 to 0.06733, saving model to 64-basiccnn1d-fasttext-los_3-best_model.hdf5
# 242/242 [==============================] - 26s 107ms/step - loss: 0.0647 - acc: 0.6317 - val_loss: 0.0673 - val_acc: 0.6215 - lr: 0.0010
# Epoch 7/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0636 - acc: 0.6339
# Epoch 7: val_loss improved from 0.06733 to 0.06723, saving model to 64-basiccnn1d-fasttext-los_3-best_model.hdf5
# 242/242 [==============================] - 26s 107ms/step - loss: 0.0636 - acc: 0.6340 - val_loss: 0.0672 - val_acc: 0.6320 - lr: 0.0010
# Epoch 8/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0630 - acc: 0.6369
# Epoch 8: val_loss improved from 0.06723 to 0.06707, saving model to 64-basiccnn1d-fasttext-los_3-best_model.hdf5
# 242/242 [==============================] - 26s 107ms/step - loss: 0.0630 - acc: 0.6370 - val_loss: 0.0671 - val_acc: 0.6343 - lr: 0.0010
# Epoch 9/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0622 - acc: 0.6451
# Epoch 9: val_loss improved from 0.06707 to 0.06677, saving model to 64-basiccnn1d-fasttext-los_3-best_model.hdf5
# 242/242 [==============================] - 26s 107ms/step - loss: 0.0622 - acc: 0.6451 - val_loss: 0.0668 - val_acc: 0.6302 - lr: 0.0010
# Epoch 10/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0615 - acc: 0.6414
# Epoch 10: val_loss did not improve from 0.06677
# 242/242 [==============================] - 26s 107ms/step - loss: 0.0615 - acc: 0.6413 - val_loss: 0.0669 - val_acc: 0.6370 - lr: 0.0010
# Epoch 11/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0609 - acc: 0.6489
# Epoch 11: val_loss improved from 0.06677 to 0.06676, saving model to 64-basiccnn1d-fasttext-los_3-best_model.hdf5
# 242/242 [==============================] - 26s 106ms/step - loss: 0.0609 - acc: 0.6491 - val_loss: 0.0668 - val_acc: 0.6361 - lr: 0.0010
# Epoch 12/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0600 - acc: 0.6515
# Epoch 12: val_loss improved from 0.06676 to 0.06671, saving model to 64-basiccnn1d-fasttext-los_3-best_model.hdf5
# 242/242 [==============================] - 26s 107ms/step - loss: 0.0600 - acc: 0.6515 - val_loss: 0.0667 - val_acc: 0.6357 - lr: 2.0000e-04
# Epoch 13/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0598 - acc: 0.6531
# Epoch 13: val_loss did not improve from 0.06671
# 242/242 [==============================] - 26s 106ms/step - loss: 0.0598 - acc: 0.6530 - val_loss: 0.0667 - val_acc: 0.6357 - lr: 2.0000e-04
# Epoch 14/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0598 - acc: 0.6572
# Epoch 14: val_loss improved from 0.06671 to 0.06666, saving model to 64-basiccnn1d-fasttext-los_3-best_model.hdf5
# 242/242 [==============================] - 26s 107ms/step - loss: 0.0599 - acc: 0.6572 - val_loss: 0.0667 - val_acc: 0.6357 - lr: 4.0000e-05
# Epoch 15/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0598 - acc: 0.6536
# Epoch 15: val_loss improved from 0.06666 to 0.06665, saving model to 64-basiccnn1d-fasttext-los_3-best_model.hdf5
# 242/242 [==============================] - 26s 107ms/step - loss: 0.0598 - acc: 0.6537 - val_loss: 0.0667 - val_acc: 0.6357 - lr: 4.0000e-05
# Epoch 16/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0596 - acc: 0.6568
# Epoch 16: val_loss did not improve from 0.06665
# 242/242 [==============================] - 26s 107ms/step - loss: 0.0596 - acc: 0.6568 - val_loss: 0.0667 - val_acc: 0.6357 - lr: 4.0000e-05
# Epoch 17/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0597 - acc: 0.6530
# Epoch 17: val_loss improved from 0.06665 to 0.06665, saving model to 64-basiccnn1d-fasttext-los_3-best_model.hdf5
# 242/242 [==============================] - 26s 107ms/step - loss: 0.0597 - acc: 0.6528 - val_loss: 0.0667 - val_acc: 0.6357 - lr: 1.0000e-05
# Epoch 18/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0597 - acc: 0.6543
# Epoch 18: val_loss improved from 0.06665 to 0.06665, saving model to 64-basiccnn1d-fasttext-los_3-best_model.hdf5
# 242/242 [==============================] - 26s 107ms/step - loss: 0.0597 - acc: 0.6542 - val_loss: 0.0666 - val_acc: 0.6357 - lr: 1.0000e-05
# Epoch 19/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0597 - acc: 0.6550
# Epoch 19: val_loss did not improve from 0.06665
# 242/242 [==============================] - 26s 107ms/step - loss: 0.0597 - acc: 0.6550 - val_loss: 0.0666 - val_acc: 0.6357 - lr: 1.0000e-05
# Epoch 20/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0598 - acc: 0.6547
# Epoch 20: val_loss did not improve from 0.06665
# 242/242 [==============================] - 26s 106ms/step - loss: 0.0597 - acc: 0.6548 - val_loss: 0.0666 - val_acc: 0.6357 - lr: 1.0000e-05
# Epoch 21/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0597 - acc: 0.6562
# Epoch 21: val_loss did not improve from 0.06665
# 242/242 [==============================] - 26s 106ms/step - loss: 0.0596 - acc: 0.6565 - val_loss: 0.0666 - val_acc: 0.6357 - lr: 1.0000e-05
# Epoch 22/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0596 - acc: 0.6564
# Epoch 22: val_loss improved from 0.06665 to 0.06665, saving model to 64-basiccnn1d-fasttext-los_3-best_model.hdf5
# 242/242 [==============================] - 26s 107ms/step - loss: 0.0596 - acc: 0.6565 - val_loss: 0.0666 - val_acc: 0.6357 - lr: 1.0000e-05
# Epoch 23/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0596 - acc: 0.6544
# Epoch 23: val_loss improved from 0.06665 to 0.06664, saving model to 64-basiccnn1d-fasttext-los_3-best_model.hdf5
# 242/242 [==============================] - 26s 107ms/step - loss: 0.0596 - acc: 0.6544 - val_loss: 0.0666 - val_acc: 0.6357 - lr: 1.0000e-05
# Epoch 24/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0596 - acc: 0.6555
# Epoch 24: val_loss improved from 0.06664 to 0.06664, saving model to 64-basiccnn1d-fasttext-los_3-best_model.hdf5
# 242/242 [==============================] - 26s 107ms/step - loss: 0.0596 - acc: 0.6555 - val_loss: 0.0666 - val_acc: 0.6357 - lr: 1.0000e-05
# Epoch 25/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0595 - acc: 0.6564
# Epoch 25: val_loss did not improve from 0.06664
# 242/242 [==============================] - 26s 107ms/step - loss: 0.0595 - acc: 0.6563 - val_loss: 0.0666 - val_acc: 0.6357 - lr: 1.0000e-05
# Epoch 26/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0597 - acc: 0.6579
# Epoch 26: val_loss improved from 0.06664 to 0.06664, saving model to 64-basiccnn1d-fasttext-los_3-best_model.hdf5
# 242/242 [==============================] - 26s 107ms/step - loss: 0.0597 - acc: 0.6577 - val_loss: 0.0666 - val_acc: 0.6357 - lr: 1.0000e-05
# Epoch 27/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0597 - acc: 0.6548
# Epoch 27: val_loss did not improve from 0.06664
# 242/242 [==============================] - 26s 107ms/step - loss: 0.0597 - acc: 0.6549 - val_loss: 0.0666 - val_acc: 0.6357 - lr: 1.0000e-05
# Epoch 28/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0596 - acc: 0.6542
# Epoch 28: val_loss improved from 0.06664 to 0.06664, saving model to 64-basiccnn1d-fasttext-los_3-best_model.hdf5
# 242/242 [==============================] - 26s 107ms/step - loss: 0.0596 - acc: 0.6544 - val_loss: 0.0666 - val_acc: 0.6357 - lr: 1.0000e-05
# Epoch 29/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0597 - acc: 0.6543
# Epoch 29: val_loss did not improve from 0.06664
# 242/242 [==============================] - 26s 107ms/step - loss: 0.0597 - acc: 0.6544 - val_loss: 0.0666 - val_acc: 0.6357 - lr: 1.0000e-05
# Epoch 30/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0597 - acc: 0.6539
# Epoch 30: val_loss improved from 0.06664 to 0.06664, saving model to 64-basiccnn1d-fasttext-los_3-best_model.hdf5
# 242/242 [==============================] - 26s 107ms/step - loss: 0.0597 - acc: 0.6539 - val_loss: 0.0666 - val_acc: 0.6357 - lr: 1.0000e-05
# Epoch 31/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0597 - acc: 0.6542
# Epoch 31: val_loss did not improve from 0.06664
# 242/242 [==============================] - 26s 107ms/step - loss: 0.0597 - acc: 0.6543 - val_loss: 0.0666 - val_acc: 0.6357 - lr: 1.0000e-05
# Epoch 32/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0596 - acc: 0.6562
# Epoch 32: val_loss improved from 0.06664 to 0.06664, saving model to 64-basiccnn1d-fasttext-los_3-best_model.hdf5
# 242/242 [==============================] - 26s 107ms/step - loss: 0.0596 - acc: 0.6563 - val_loss: 0.0666 - val_acc: 0.6357 - lr: 1.0000e-05
# Epoch 33/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0596 - acc: 0.6573
# Epoch 33: val_loss improved from 0.06664 to 0.06664, saving model to 64-basiccnn1d-fasttext-los_3-best_model.hdf5
# 242/242 [==============================] - 26s 107ms/step - loss: 0.0596 - acc: 0.6572 - val_loss: 0.0666 - val_acc: 0.6357 - lr: 1.0000e-05
# Epoch 34/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0596 - acc: 0.6534
# Epoch 34: val_loss did not improve from 0.06664
# 242/242 [==============================] - 26s 107ms/step - loss: 0.0596 - acc: 0.6534 - val_loss: 0.0666 - val_acc: 0.6357 - lr: 1.0000e-05
# Epoch 35/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0596 - acc: 0.6555
# Epoch 35: val_loss did not improve from 0.06664
# 242/242 [==============================] - 26s 106ms/step - loss: 0.0596 - acc: 0.6556 - val_loss: 0.0666 - val_acc: 0.6357 - lr: 1.0000e-05
# Epoch 36/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0596 - acc: 0.6547
# Epoch 36: val_loss did not improve from 0.06664
# 242/242 [==============================] - 26s 107ms/step - loss: 0.0596 - acc: 0.6546 - val_loss: 0.0666 - val_acc: 0.6357 - lr: 1.0000e-05
# Epoch 37/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0596 - acc: 0.6550
# Epoch 37: val_loss did not improve from 0.06664
# 242/242 [==============================] - 26s 107ms/step - loss: 0.0596 - acc: 0.6548 - val_loss: 0.0666 - val_acc: 0.6357 - lr: 1.0000e-05
# Epoch 38/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0596 - acc: 0.6551
# Epoch 38: val_loss did not improve from 0.06664
# 242/242 [==============================] - 26s 107ms/step - loss: 0.0596 - acc: 0.6553 - val_loss: 0.0666 - val_acc: 0.6357 - lr: 1.0000e-05
# 138/138 [==============================] - 2s 12ms/step
# AUC:  0.6968415280415483 AUPRC:  0.6352027631178664 F1:  0.2917202917202918
# 138/138 [==============================] - 2s 11ms/step
# 0.6968391990972165 0.635190605917656 0.6241748235829729 0.29050279329608936
# Problem type:  los_7
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0474 - acc: 0.9170
# Epoch 1: val_loss improved from inf to 0.03432, saving model to 64-basiccnn1d-fasttext-los_7-best_model.hdf5
# 242/242 [==============================] - 28s 108ms/step - loss: 0.0474 - acc: 0.9170 - val_loss: 0.0343 - val_acc: 0.9238 - lr: 0.0010
# Epoch 2/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0321 - acc: 0.9224
# Epoch 2: val_loss improved from 0.03432 to 0.03182, saving model to 64-basiccnn1d-fasttext-los_7-best_model.hdf5
# 242/242 [==============================] - 26s 106ms/step - loss: 0.0321 - acc: 0.9224 - val_loss: 0.0318 - val_acc: 0.9238 - lr: 0.0010
# Epoch 3/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0295 - acc: 0.9224
# Epoch 3: val_loss improved from 0.03182 to 0.03074, saving model to 64-basiccnn1d-fasttext-los_7-best_model.hdf5
# 242/242 [==============================] - 26s 106ms/step - loss: 0.0295 - acc: 0.9224 - val_loss: 0.0307 - val_acc: 0.9238 - lr: 0.0010
# Epoch 4/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0281 - acc: 0.9225
# Epoch 4: val_loss improved from 0.03074 to 0.02990, saving model to 64-basiccnn1d-fasttext-los_7-best_model.hdf5
# 242/242 [==============================] - 26s 106ms/step - loss: 0.0281 - acc: 0.9224 - val_loss: 0.0299 - val_acc: 0.9238 - lr: 0.0010
# Epoch 5/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0271 - acc: 0.9224
# Epoch 5: val_loss improved from 0.02990 to 0.02937, saving model to 64-basiccnn1d-fasttext-los_7-best_model.hdf5
# 242/242 [==============================] - 26s 106ms/step - loss: 0.0271 - acc: 0.9223 - val_loss: 0.0294 - val_acc: 0.9238 - lr: 0.0010
# Epoch 6/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0261 - acc: 0.9223
# Epoch 6: val_loss improved from 0.02937 to 0.02888, saving model to 64-basiccnn1d-fasttext-los_7-best_model.hdf5
# 242/242 [==============================] - 26s 106ms/step - loss: 0.0261 - acc: 0.9223 - val_loss: 0.0289 - val_acc: 0.9238 - lr: 0.0010
# Epoch 7/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0255 - acc: 0.9223
# Epoch 7: val_loss improved from 0.02888 to 0.02854, saving model to 64-basiccnn1d-fasttext-los_7-best_model.hdf5
# 242/242 [==============================] - 26s 106ms/step - loss: 0.0255 - acc: 0.9223 - val_loss: 0.0285 - val_acc: 0.9238 - lr: 0.0010
# Epoch 8/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0250 - acc: 0.9223
# Epoch 8: val_loss improved from 0.02854 to 0.02819, saving model to 64-basiccnn1d-fasttext-los_7-best_model.hdf5
# 242/242 [==============================] - 26s 106ms/step - loss: 0.0250 - acc: 0.9223 - val_loss: 0.0282 - val_acc: 0.9238 - lr: 0.0010
# Epoch 9/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0244 - acc: 0.9225
# Epoch 9: val_loss improved from 0.02819 to 0.02796, saving model to 64-basiccnn1d-fasttext-los_7-best_model.hdf5
# 242/242 [==============================] - 26s 106ms/step - loss: 0.0244 - acc: 0.9224 - val_loss: 0.0280 - val_acc: 0.9238 - lr: 0.0010
# Epoch 10/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0238 - acc: 0.9226
# Epoch 10: val_loss improved from 0.02796 to 0.02777, saving model to 64-basiccnn1d-fasttext-los_7-best_model.hdf5
# 242/242 [==============================] - 26s 107ms/step - loss: 0.0239 - acc: 0.9225 - val_loss: 0.0278 - val_acc: 0.9238 - lr: 0.0010
# Epoch 11/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0234 - acc: 0.9224
# Epoch 11: val_loss improved from 0.02777 to 0.02753, saving model to 64-basiccnn1d-fasttext-los_7-best_model.hdf5
# 242/242 [==============================] - 26s 106ms/step - loss: 0.0234 - acc: 0.9223 - val_loss: 0.0275 - val_acc: 0.9238 - lr: 0.0010
# Epoch 12/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0230 - acc: 0.9223
# Epoch 12: val_loss improved from 0.02753 to 0.02749, saving model to 64-basiccnn1d-fasttext-los_7-best_model.hdf5
# 242/242 [==============================] - 26s 106ms/step - loss: 0.0230 - acc: 0.9223 - val_loss: 0.0275 - val_acc: 0.9238 - lr: 0.0010
# Epoch 13/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0226 - acc: 0.9226
# Epoch 13: val_loss improved from 0.02749 to 0.02725, saving model to 64-basiccnn1d-fasttext-los_7-best_model.hdf5
# 242/242 [==============================] - 26s 106ms/step - loss: 0.0226 - acc: 0.9226 - val_loss: 0.0272 - val_acc: 0.9238 - lr: 0.0010
# Epoch 14/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0222 - acc: 0.9227
# Epoch 14: val_loss improved from 0.02725 to 0.02712, saving model to 64-basiccnn1d-fasttext-los_7-best_model.hdf5
# ...
# Epoch 7: val_loss improved from 0.01920 to 0.01873, saving model to 64-basiccnn1d-fasttext-mort_icu-best_model.hdf5
# 242/242 [==============================] - 26s 105ms/step - loss: 0.0158 - acc: 0.9461 - val_loss: 0.0187 - val_acc: 0.9444 - lr: 0.0010
# Epoch 8/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0151 - acc: 0.9464
# Epoch 8: val_loss improved from 0.01873 to 0.01859, saving model to 64-basiccnn1d-fasttext-mort_icu-best_model.hdf5
# 242/242 [==============================] - 25s 105ms/step - loss: 0.0151 - acc: 0.9464 - val_loss: 0.0186 - val_acc: 0.9435 - lr: 0.0010
# Epoch 9/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0147 - acc: 0.9473
# Epoch 9: val_loss did not improve from 0.01859
# 242/242 [==============================] - 25s 105ms/step - loss: 0.0147 - acc: 0.9473 - val_loss: 0.0187 - val_acc: 0.9435 - lr: 0.0010
# Epoch 10/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0143 - acc: 0.9470
# Epoch 10: val_loss improved from 0.01859 to 0.01847, saving model to 64-basiccnn1d-fasttext-mort_icu-best_model.hdf5
# 242/242 [==============================] - 26s 106ms/step - loss: 0.0143 - acc: 0.9471 - val_loss: 0.0185 - val_acc: 0.9439 - lr: 0.0010
# Epoch 11/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0138 - acc: 0.9481
# Epoch 11: val_loss improved from 0.01847 to 0.01834, saving model to 64-basiccnn1d-fasttext-mort_icu-best_model.hdf5
# 242/242 [==============================] - 26s 107ms/step - loss: 0.0138 - acc: 0.9481 - val_loss: 0.0183 - val_acc: 0.9439 - lr: 0.0010
# Epoch 12/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0134 - acc: 0.9490
# Epoch 12: val_loss did not improve from 0.01834
# 242/242 [==============================] - 26s 107ms/step - loss: 0.0133 - acc: 0.9490 - val_loss: 0.0185 - val_acc: 0.9439 - lr: 0.0010
# Epoch 13/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0130 - acc: 0.9503
# Epoch 13: val_loss did not improve from 0.01834
# 242/242 [==============================] - 26s 106ms/step - loss: 0.0130 - acc: 0.9503 - val_loss: 0.0184 - val_acc: 0.9439 - lr: 0.0010
# Epoch 14/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0125 - acc: 0.9495
# Epoch 14: val_loss did not improve from 0.01834
# 242/242 [==============================] - 26s 107ms/step - loss: 0.0126 - acc: 0.9494 - val_loss: 0.0184 - val_acc: 0.9439 - lr: 2.0000e-04
# Epoch 15/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0125 - acc: 0.9512
# Epoch 15: val_loss did not improve from 0.01834
# 242/242 [==============================] - 27s 112ms/step - loss: 0.0125 - acc: 0.9512 - val_loss: 0.0184 - val_acc: 0.9439 - lr: 2.0000e-04
# Epoch 16/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0124 - acc: 0.9507
# Epoch 16: val_loss did not improve from 0.01834
# 242/242 [==============================] - 26s 108ms/step - loss: 0.0124 - acc: 0.9506 - val_loss: 0.0184 - val_acc: 0.9439 - lr: 4.0000e-05
# 138/138 [==============================] - 2s 12ms/step
# AUC:  0.8792283921218358 AUPRC:  0.5083293545476327 F1:  0.3247422680412371
# 138/138 [==============================] - 2s 11ms/step
# 0.8806517146234482 0.5117828664985566 0.9394491236057364 0.3036649214659686
# Problem type:  los_3
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0840 - acc: 0.5959
# Epoch 1: val_loss improved from inf to 0.07131, saving model to 64-basiccnn1d-fasttext-los_3-best_model.hdf5
# 242/242 [==============================] - 27s 106ms/step - loss: 0.0840 - acc: 0.5960 - val_loss: 0.0713 - val_acc: 0.6078 - lr: 0.0010
# Epoch 2/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0704 - acc: 0.6092
# Epoch 2: val_loss improved from 0.07131 to 0.06904, saving model to 64-basiccnn1d-fasttext-los_3-best_model.hdf5
# 242/242 [==============================] - 25s 105ms/step - loss: 0.0704 - acc: 0.6092 - val_loss: 0.0690 - val_acc: 0.6243 - lr: 0.0010
# Epoch 3/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0675 - acc: 0.6215
# Epoch 3: val_loss improved from 0.06904 to 0.06810, saving model to 64-basiccnn1d-fasttext-los_3-best_model.hdf5
# 242/242 [==============================] - 25s 105ms/step - loss: 0.0675 - acc: 0.6215 - val_loss: 0.0681 - val_acc: 0.6202 - lr: 0.0010
# Epoch 4/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0656 - acc: 0.6242
# Epoch 4: val_loss improved from 0.06810 to 0.06735, saving model to 64-basiccnn1d-fasttext-los_3-best_model.hdf5
# 242/242 [==============================] - 26s 106ms/step - loss: 0.0656 - acc: 0.6243 - val_loss: 0.0673 - val_acc: 0.6302 - lr: 0.0010
# Epoch 5/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0642 - acc: 0.6279
# Epoch 5: val_loss improved from 0.06735 to 0.06680, saving model to 64-basiccnn1d-fasttext-los_3-best_model.hdf5
# 242/242 [==============================] - 26s 106ms/step - loss: 0.0642 - acc: 0.6280 - val_loss: 0.0668 - val_acc: 0.6233 - lr: 0.0010
# Epoch 6/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0633 - acc: 0.6332
# Epoch 6: val_loss improved from 0.06680 to 0.06651, saving model to 64-basiccnn1d-fasttext-los_3-best_model.hdf5
# 242/242 [==============================] - 25s 104ms/step - loss: 0.0633 - acc: 0.6331 - val_loss: 0.0665 - val_acc: 0.6329 - lr: 0.0010
# Epoch 7/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0625 - acc: 0.6367
# Epoch 7: val_loss did not improve from 0.06651
# 242/242 [==============================] - 25s 104ms/step - loss: 0.0625 - acc: 0.6367 - val_loss: 0.0666 - val_acc: 0.6379 - lr: 0.0010
# Epoch 8/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0616 - acc: 0.6437
# Epoch 8: val_loss improved from 0.06651 to 0.06615, saving model to 64-basiccnn1d-fasttext-los_3-best_model.hdf5
# 242/242 [==============================] - 25s 103ms/step - loss: 0.0616 - acc: 0.6438 - val_loss: 0.0662 - val_acc: 0.6284 - lr: 0.0010
# Epoch 9/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0609 - acc: 0.6468
# Epoch 9: val_loss improved from 0.06615 to 0.06610, saving model to 64-basiccnn1d-fasttext-los_3-best_model.hdf5
# 242/242 [==============================] - 25s 105ms/step - loss: 0.0609 - acc: 0.6466 - val_loss: 0.0661 - val_acc: 0.6320 - lr: 0.0010
# Epoch 10/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0602 - acc: 0.6502
# Epoch 10: val_loss did not improve from 0.06610
# 242/242 [==============================] - 25s 104ms/step - loss: 0.0602 - acc: 0.6500 - val_loss: 0.0664 - val_acc: 0.6338 - lr: 0.0010
# Epoch 11/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0595 - acc: 0.6529
# Epoch 11: val_loss did not improve from 0.06610
# 242/242 [==============================] - 25s 104ms/step - loss: 0.0595 - acc: 0.6530 - val_loss: 0.0663 - val_acc: 0.6343 - lr: 2.0000e-04
# Epoch 12/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0593 - acc: 0.6558
# Epoch 12: val_loss did not improve from 0.06610
# 242/242 [==============================] - 25s 103ms/step - loss: 0.0593 - acc: 0.6559 - val_loss: 0.0663 - val_acc: 0.6357 - lr: 2.0000e-04
# Epoch 13/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0591 - acc: 0.6574
# Epoch 13: val_loss did not improve from 0.06610
# 242/242 [==============================] - 25s 105ms/step - loss: 0.0590 - acc: 0.6576 - val_loss: 0.0662 - val_acc: 0.6357 - lr: 4.0000e-05
# Epoch 14/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0592 - acc: 0.6545
# Epoch 14: val_loss did not improve from 0.06610
# 242/242 [==============================] - 25s 103ms/step - loss: 0.0592 - acc: 0.6544 - val_loss: 0.0662 - val_acc: 0.6357 - lr: 4.0000e-05
# 138/138 [==============================] - 2s 12ms/step
# AUC:  0.6996671726827532 AUPRC:  0.638591836031698 F1:  0.30158052114480993
# 138/138 [==============================] - 2s 11ms/step
# 0.6990723391281702 0.6383454436984479 0.6241748235829729 0.2812363952982151
# Problem type:  los_7
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0454 - acc: 0.9184
# Epoch 1: val_loss improved from inf to 0.03399, saving model to 64-basiccnn1d-fasttext-los_7-best_model.hdf5
# 242/242 [==============================] - 27s 105ms/step - loss: 0.0455 - acc: 0.9184 - val_loss: 0.0340 - val_acc: 0.9238 - lr: 0.0010
# Epoch 2/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0318 - acc: 0.9223
# Epoch 2: val_loss improved from 0.03399 to 0.03182, saving model to 64-basiccnn1d-fasttext-los_7-best_model.hdf5
# 242/242 [==============================] - 25s 105ms/step - loss: 0.0318 - acc: 0.9223 - val_loss: 0.0318 - val_acc: 0.9238 - lr: 0.0010
# Epoch 3/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0295 - acc: 0.9225
# Epoch 3: val_loss improved from 0.03182 to 0.03070, saving model to 64-basiccnn1d-fasttext-los_7-best_model.hdf5
# 242/242 [==============================] - 26s 105ms/step - loss: 0.0295 - acc: 0.9224 - val_loss: 0.0307 - val_acc: 0.9238 - lr: 0.0010
# Epoch 4/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0280 - acc: 0.9225
# Epoch 4: val_loss improved from 0.03070 to 0.02991, saving model to 64-basiccnn1d-fasttext-los_7-best_model.hdf5
# 242/242 [==============================] - 25s 105ms/step - loss: 0.0280 - acc: 0.9225 - val_loss: 0.0299 - val_acc: 0.9238 - lr: 0.0010
# Epoch 5/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0270 - acc: 0.9223
# Epoch 5: val_loss improved from 0.02991 to 0.02943, saving model to 64-basiccnn1d-fasttext-los_7-best_model.hdf5
# 242/242 [==============================] - 25s 105ms/step - loss: 0.0270 - acc: 0.9223 - val_loss: 0.0294 - val_acc: 0.9238 - lr: 0.0010
# Epoch 6/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0262 - acc: 0.9225
# Epoch 6: val_loss improved from 0.02943 to 0.02907, saving model to 64-basiccnn1d-fasttext-los_7-best_model.hdf5
# 242/242 [==============================] - 26s 106ms/step - loss: 0.0262 - acc: 0.9225 - val_loss: 0.0291 - val_acc: 0.9238 - lr: 0.0010
# Epoch 7/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0254 - acc: 0.9223
# Epoch 7: val_loss improved from 0.02907 to 0.02878, saving model to 64-basiccnn1d-fasttext-los_7-best_model.hdf5
# 242/242 [==============================] - 25s 105ms/step - loss: 0.0254 - acc: 0.9224 - val_loss: 0.0288 - val_acc: 0.9238 - lr: 0.0010
# Epoch 8/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0248 - acc: 0.9223
# Epoch 8: val_loss improved from 0.02878 to 0.02838, saving model to 64-basiccnn1d-fasttext-los_7-best_model.hdf5
# 242/242 [==============================] - 25s 105ms/step - loss: 0.0248 - acc: 0.9223 - val_loss: 0.0284 - val_acc: 0.9238 - lr: 0.0010
# Epoch 9/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0242 - acc: 0.9223
# Epoch 9: val_loss improved from 0.02838 to 0.02813, saving model to 64-basiccnn1d-fasttext-los_7-best_model.hdf5
# 242/242 [==============================] - 26s 105ms/step - loss: 0.0242 - acc: 0.9224 - val_loss: 0.0281 - val_acc: 0.9238 - lr: 0.0010
# Epoch 10/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0236 - acc: 0.9224
# Epoch 10: val_loss improved from 0.02813 to 0.02798, saving model to 64-basiccnn1d-fasttext-los_7-best_model.hdf5
# 242/242 [==============================] - 25s 105ms/step - loss: 0.0236 - acc: 0.9224 - val_loss: 0.0280 - val_acc: 0.9238 - lr: 0.0010
# Epoch 11/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0232 - acc: 0.9226
# Epoch 11: val_loss improved from 0.02798 to 0.02784, saving model to 64-basiccnn1d-fasttext-los_7-best_model.hdf5
# 242/242 [==============================] - 25s 105ms/step - loss: 0.0232 - acc: 0.9225 - val_loss: 0.0278 - val_acc: 0.9238 - lr: 0.0010
# Epoch 12/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0227 - acc: 0.9225
# Epoch 12: val_loss improved from 0.02784 to 0.02764, saving model to 64-basiccnn1d-fasttext-los_7-best_model.hdf5
# 242/242 [==============================] - 25s 105ms/step - loss: 0.0227 - acc: 0.9225 - val_loss: 0.0276 - val_acc: 0.9238 - lr: 0.0010
# Epoch 13/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0224 - acc: 0.9226
# Epoch 13: val_loss improved from 0.02764 to 0.02755, saving model to 64-basiccnn1d-fasttext-los_7-best_model.hdf5
# 242/242 [==============================] - 26s 106ms/step - loss: 0.0224 - acc: 0.9225 - val_loss: 0.0276 - val_acc: 0.9238 - lr: 0.0010
# Epoch 14/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0220 - acc: 0.9224
# Epoch 14: val_loss improved from 0.02755 to 0.02746, saving model to 64-basiccnn1d-fasttext-los_7-best_model.hdf5
# 242/242 [==============================] - 25s 105ms/step - loss: 0.0220 - acc: 0.9224 - val_loss: 0.0275 - val_acc: 0.9238 - lr: 0.0010
# Epoch 15/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0216 - acc: 0.9225
# Epoch 15: val_loss improved from 0.02746 to 0.02739, saving model to 64-basiccnn1d-fasttext-los_7-best_model.hdf5
# 242/242 [==============================] - 25s 105ms/step - loss: 0.0216 - acc: 0.9226 - val_loss: 0.0274 - val_acc: 0.9238 - lr: 0.0010
# Epoch 16/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0212 - acc: 0.9228
# Epoch 16: val_loss improved from 0.02739 to 0.02733, saving model to 64-basiccnn1d-fasttext-los_7-best_model.hdf5
# 242/242 [==============================] - 25s 105ms/step - loss: 0.0212 - acc: 0.9229 - val_loss: 0.0273 - val_acc: 0.9238 - lr: 0.0010
# Epoch 17/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0209 - acc: 0.9226
# Epoch 17: val_loss did not improve from 0.02733
# 242/242 [==============================] - 27s 114ms/step - loss: 0.0209 - acc: 0.9227 - val_loss: 0.0274 - val_acc: 0.9238 - lr: 0.0010
# Epoch 18/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0206 - acc: 0.9229
# Epoch 18: val_loss improved from 0.02733 to 0.02725, saving model to 64-basiccnn1d-fasttext-los_7-best_model.hdf5
# 242/242 [==============================] - 28s 114ms/step - loss: 0.0205 - acc: 0.9230 - val_loss: 0.0272 - val_acc: 0.9238 - lr: 0.0010
# Epoch 19/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0203 - acc: 0.9232
# Epoch 19: val_loss did not improve from 0.02725
# 242/242 [==============================] - 26s 107ms/step - loss: 0.0202 - acc: 0.9232 - val_loss: 0.0273 - val_acc: 0.9238 - lr: 2.0000e-04
# Epoch 20/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0201 - acc: 0.9232
# Epoch 20: val_loss did not improve from 0.02725
# 242/242 [==============================] - 26s 107ms/step - loss: 0.0201 - acc: 0.9231 - val_loss: 0.0273 - val_acc: 0.9238 - lr: 2.0000e-04
# Epoch 21/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0200 - acc: 0.9230
# Epoch 21: val_loss did not improve from 0.02725
# 242/242 [==============================] - 26s 108ms/step - loss: 0.0200 - acc: 0.9230 - val_loss: 0.0273 - val_acc: 0.9238 - lr: 4.0000e-05
# Epoch 22/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0200 - acc: 0.9230
# Epoch 22: val_loss did not improve from 0.02725
# 242/242 [==============================] - 26s 108ms/step - loss: 0.0200 - acc: 0.9231 - val_loss: 0.0273 - val_acc: 0.9238 - lr: 4.0000e-05
# Epoch 23/100
# 241/242 [============================>.] - ETA: 0s - loss: 0.0200 - acc: 0.9230
# Epoch 23: val_loss did not improve from 0.02725
# 242/242 [==============================] - 26s 107ms/step - loss: 0.0200 - acc: 0.9231 - val_loss: 0.0273 - val_acc: 0.9238 - lr: 1.0000e-05
# 138/138 [==============================] - 2s 12ms/step
# AUC:  0.7228924763219625 AUPRC:  0.21291019692761493 F1:  0.01680672268907563
# 138/138 [==============================] - 2s 12ms/step
# 0.7222416887325973 0.21332456339384503 0.9201001593444116 0.01680672268907563
